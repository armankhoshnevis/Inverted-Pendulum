# %%
# Load libraries
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
# print(gym.__file__)

# %%
# Load the gym environment (Inverted pendulum - Swing-up problem)
env = gym.make("Pendulum-v1", g=9.81, render_mode="rgb_array")

# General information about the environment
envs = gym.envs.registry
print(envs["Pendulum-v1"])

print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# EnvSpec(id='Pendulum-v1', entry_point='gym.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pendulum', version=1)
# Observation space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# Action space: Box(-2.0, 2.0, (1,), float32)

# %% [markdown]
# ### Observation and action space
# The observation is a ndarray with shape (3,) representing the x-y coordinates of the pendulum’s free end and its angular velocity.
#
# obs[0]: x = cos(theta) --> [-1, 1], obs[1]: y = sin(theta) --> [-1, 1], obs[2]: Angular velocity --> [-8, 8]
#
# ![Problem schematic](../pendulum.png)
#
# The action is a ndarray with shape (1,) representing the torque applied to free end of the pendulum.
# T: A continious torque within the range of [-2, 2] (N.m)

# %%
# Initialize the environment with a random seed
obs, info = env.reset(seed=42)
print('Our first observation:', obs)
img = env.render()
plt.imshow(img);
# Out:
# Our first observation: [-0.14995256  0.9886932  -0.12224312]

# %% [markdown]
# ### Costumized Initialization
# In order to initialize the state of the pendulum, especially its angle, minor changes are applied to the reset funciton, which was defined previously in the pendulum class.
#
# In the modified version of the reset function, the initial angle of pendulum is either within the range of $[\frac{3\pi}{4}, \pi]$ or $[-\pi, \frac{-3\pi}{4}]$ (see the first figure).
#
# In the original version, the initial angle and angular velocity is randomly and uniformly choosed within the default range or the provided range by the user.
#
# In this modifed version, the initial angle is first randomly and uniformly picked within the above-mentioned range, then it is given to the reset function, and this function will not change its value.

# %%
# Test: Costumized initialization (third and fourth quadrant)
theta_initial = np.random.uniform(low=-np.pi/6, high=np.pi/6)
initial_theta_dot = np.random.uniform(low=-1, high = 1)

# This condition ensures that theta falls with the above-mentioned range 
# based on the definition of the normalized angle and the coordinate system in first figure above.
if theta_initial<0:
    theta_initial = np.pi + theta_initial
else:
    theta_initial = -(np.pi - theta_initial)

options = {
    "x_init": theta_initial,  # or 0 for test
    "y_init": initial_theta_dot  # or 0 for test
}

observation, info = env.reset(options=options)
img = env.render()
plt.imshow(img);

# %%
# Test: Costumized initialization (first and second quadrant)
theta_initial = np.random.uniform(low=-np.pi/6, high=np.pi/6)
initial_theta_dot = np.random.uniform(low=-1, high = 1)

options = {
    "x_init": theta_initial,  # or 0 for test
    "y_init": initial_theta_dot  # or 0 for test
}

observation, info = env.reset(options=options)
img = env.render()
plt.imshow(img);

# %% [markdown]
# ### How to apply these changes to the source code!
#
# Run this code: `print(gym.__file__)` and open the pendulum.py file.
# Then, replace the following commented code with the `reset` function.

# %%
'''
def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        if options is None:
            high = np.array([DEFAULT_X, DEFAULT_Y])
            low = -high  # We enforce symmetric limits.
            self.state = self.np_random.uniform(low=low, high=high)
            self.last_u = None
        else:
            # Note that if you use custom reset bounds, it may lead to out-of-bound
            # state/observations.
            x = options.get("x_init") if "x_init" in options else DEFAULT_X
            y = options.get("y_init") if "y_init" in options else DEFAULT_Y
            x = utils.verify_number_and_cast(x)
            y = utils.verify_number_and_cast(y)
            self.state = np.array([x, y])
            self.last_u = None

        if self.render_mode == "human":
            self.render()
        return self._get_obs(), {}
''';

# %%
# Test: Applying single random actions and visulize its effects
action = np.array([-2])  # CCW torqu
obs, reward, done, truncated, info = env.step(action)
print(obs, reward, done, truncated, info)
print('Theta angle (deg) = ', np.arctan2(obs[1], obs[0]) * 180/np.pi)
img = env.render()
plt.imshow(img);
# Out:
# [ 0.8944197  -0.44722846 -0.91340643] -0.1886253515606034 False False {}
# Theta angle (deg) =  -26.56600370129167

# %% [markdown]
# ### Random Action Results

# %%
# Perform random actions

# Lists to store the observations
x_coordinate_values = []
y_coordinate_values = []
angular_velocity = []
action_values = []
reward_values = []
angle_deg_values = []
angle_rad_values = []

# Initialize the environment before the begining of the episode
initial_observation = env.reset(seed=42)

# Change the number of time steps per episode; the default number is 200
# env._max_episode_steps = 500


for _ in range(env._max_episode_steps):
    # Random action and its observation
    random_action = env.action_space.sample()
    observation, reward, _, _, _ = env.step(random_action)
    
    # Calculate the theta
    theta_rad = np.arctan2(observation[1], observation[0])
    theta_deg = np.degrees(theta_rad)
    
    # Record the actions and observations
    action_values.append(random_action)
    x_coordinate_values.append(observation[0])
    y_coordinate_values.append(observation[1])
    angular_velocity.append(observation[2])
    reward_values.append(reward)
    angle_rad_values.append(theta_rad)
    angle_deg_values.append(theta_deg)
    
time_steps = np.arange(env._max_episode_steps)

plt.figure(figsize=(10, 6))

plt.plot(time_steps, x_coordinate_values, label='x')
plt.plot(time_steps, y_coordinate_values, label='y')
plt.plot(time_steps, angular_velocity, label='Angular Velocity')
# plt.plot(time_steps, action_values, label='Applied Torque')
plt.plot(time_steps, reward_values, label='Reward')
plt.plot(time_steps, angle_rad_values, label='Angle')

plt.xlabel('Time Steps')
plt.ylabel('Observation Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs = axs.flatten()

axs[0].plot(time_steps, x_coordinate_values, label='x')
axs[0].plot(time_steps, y_coordinate_values, label='y')
axs[0].plot(time_steps, angle_rad_values, label='theta')
axs[0].set_ylabel('X/Y Coordinate (m) & theta (rad)')
axs[0].legend()

axs[1].plot(time_steps, angular_velocity)
axs[1].set_ylabel('Angular Velocity (rad/s)')
axs[1].set_ylim([-8, 8])

axs[2].plot(time_steps, action_values)
axs[2].set_ylabel('Applied Torque (N.m)')
axs[2].set_xlabel('Time Steps')

axs[3].plot(time_steps, reward_values)
axs[3].set_ylabel('Reward')
axs[3].set_xlabel('Time Steps')
axs[3].set_ylim([-16, 0])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Reward equation
# $r = -(\theta^2 + 0.1 \times {\dot{\theta}}^2 + 0.001 \times torque^2)$
#
# where $\theta$ is the pendulum’s angle normalized between $[-\pi, \pi]$ (with 0 being in the upright position). Based on the above equation, the minimum reward that can be obtained is $-(\pi^2 + 0.1 \times 8^2 + 0.001 \times 2^2) = -16.2736044$, while the maximum reward is zero (pendulum is upright with zero velocity and no torque applied).

# %% [markdown]
# ### Linear Q-Learning + $\epsilon$-greedy Policy

# %%
# Extract features
def get_features(state, action):
    x, y, th_dot = state  # th_dot: theta_dot
    th = np.arctan2(y, x)  # th: theta
    torque = action[0]
    
    features = np.array([th, th_dot, torque,
                         th**2, th_dot**2, torque*th_dot])
    return features

# Approximate the Q-value (Linear)
def q_function(state, action, w):
    x = get_features(state, action)
    output = np.dot(x, w)
    return output

# Select an action that maximize the q value (Greedy action)
def get_action_greedy(state, w):
     # Discretize the action
    discrete_actions= np.linspace(env.action_space.low[0], env.action_space.high[0], 101)
    qs = []
    qs = [q_function(state, np.array([action]), w) for action in discrete_actions]
    max_index = np.argmax(qs)
    action = discrete_actions[max_index]
    return np.array([action])

# Epsilon-Greedy policy to select the next action
def get_action_epsilon_greedy(state, w, epsilon):
    discrete_actions= np.linspace(env.action_space.low[0], env.action_space.high[0], 101)
    if np.random.rand() < epsilon:
        # Exploration by selecting a random action with a probability of epsilon
        action = np.random.choice(discrete_actions)
    else:
        # Exploitation by selecting an action with the highest immediate reward
        qs = [q_function(state, np.array([action]), w) for action in discrete_actions]
        max_index = np.argmax(qs)
        action = discrete_actions[max_index]
    return np.array([action])

# %%
# Learning parameters
learning_rate = 1e-6  # alpha or the learning rate for the SGD optimiation of weights
discount_factor = 0.97  # gamma or the discount factor for the Q-Learning

# Epsilon-greedy parameters
epsilon = 0.9
epsilon_decay = 0.995
epsilon_min = 0.005

# Initialize the weights
w = np.random.uniform(low=-0.1, high=0.1, size=(get_features(env.reset()[0], np.array([0.])).shape[0],))

# Loop parameters
num_episode = 3000
env._max_episode_steps = 800
num_time_steps = env._max_episode_steps

# Pre-allocation
x_coordinate_values = np.zeros([num_episode, num_time_steps])
y_coordinate_values = np.zeros([num_episode, num_time_steps])
th_values = np.zeros([num_episode, num_time_steps])
th_dot_values = np.zeros([num_episode, num_time_steps])
action_values = np.zeros([num_episode, num_time_steps])
reward_values = np.zeros([num_episode, num_time_steps])
weight_values = np.zeros([num_episode, num_time_steps, len(w)])
td_error_values = np.zeros([num_episode, num_time_steps])
epsilon_values = np.zeros([num_episode])

for episode in range(num_episode):
    total_reward = 0  # Reset the total reward
    
    # Initialize the theta and theta_dot (Pendulum is in the first and second quadrant)
    initial_theta_dot = np.random.uniform(low=-0.1, high = 0.1)
    theta_initial = np.random.uniform(low=-np.pi/6, high=np.pi/6)
    
    # This condition is used for initializing the pendulum in third and fourth quadrant
    '''
    if theta_initial<0:
        theta_initial = np.pi + theta_initial
    else:
        theta_initial = -(np.pi - theta_initial)
    '''

    options = {
        "x_init": theta_initial,  # 0,
        "y_init": initial_theta_dot  # 0
    }

    s, _ = env.reset(options=options)  # Initialize the environment
    
    for time_step in range(num_time_steps):
        env.render()  # For visualization
        
        # Store the x and y coordinates and angular velocity
        x_coordinate_values[episode, time_step] = s[0]
        y_coordinate_values[episode, time_step] = s[1]
        th_values[episode, time_step] = np.arctan2(s[1], s[0]) * 180/np.pi
        th_dot_values[episode, time_step] = s[2]
        
        # Select the current action
        a = get_action_epsilon_greedy(s, w, epsilon)
        
        # Take the current action, observe the new state (s'), and calculate the immediate reward (r')
        s_prime, r_prime, done, truncated, info = env.step(a)
        
        # Select the greedy action
        a_maximizer_q = get_action_greedy(s_prime, w)
        
        # Calculate the q values
        q_current = q_function(s, a, w)
        q_maximized = q_function(s_prime, a_maximizer_q, w)

        # Calculate and store the temporal difference error
        td_error = (r_prime + (discount_factor * q_maximized)) - q_current
        td_error_values[episode, time_step] = td_error
        
        # Obtain the features
        features = get_features(s, a)
        
        # Store the weights
        weight_values[episode, time_step, :] = w
        
        # Update the weights (SGD)
        w = w + learning_rate * td_error * features
        
        # Update the current state
        s = s_prime
        
        # Store the current action (a)
        action_values[episode, time_step] = a[0]
        
        # Store the rewards
        reward_values[episode, time_step] = r_prime
        
        if time_step%30 == 0:
           print(f'Episode: {episode}, Time step: {time_step}')
        
        # Store and update the epsilon value (Multiplicative Decay)
        epsilon_values[episode, time_step] = epsilon
        epsilon = max(epsilon_min, epsilon*epsilon_decay)
    
    # Reset the epsilon value
    epsilon = 0.9

env.close()

np.save('x_coordinate_values.npy', x_coordinate_values)
np.save('y_coordinate_values.npy', y_coordinate_values)
np.save('th_values.npy', th_values)
np.save('th_dot_values.npy', th_dot_values)
np.save('action_values.npy', action_values)
np.save('reward_values.npy', reward_values)
np.save('weight_values.npy', weight_values)
np.save('td_error_values.npy', td_error_values)
np.save('epsilon_values.npy', epsilon_values)
np.save('num_episode.npy', num_episode)
np.save('num_time_steps.npy', num_time_steps)
# Out:
# Episode: 0, Time step: 0
# Episode: 0, Time step: 30
# Episode: 0, Time step: 60
# Episode: 0, Time step: 90
# Episode: 0, Time step: 120
# Episode: 0, Time step: 150
# Episode: 0, Time step: 180
# Episode: 0, Time step: 210
# Episode: 0, Time step: 240
# Episode: 0, Time step: 270
# Episode: 0, Time step: 300
# Episode: 0, Time step: 330
# Episode: 0, Time step: 360
# Episode: 0, Time step: 390
# Episode: 0, Time step: 420
# Episode: 0, Time step: 450
# Episode: 0, Time step: 480
# Episode: 0, Time step: 510
# Episode: 0, Time step: 540
# Episode: 0, Time step: 570
# Episode: 0, Time step: 600
# Episode: 0, Time step: 630
# Episode: 0, Time step: 660
# Episode: 0, Time step: 690
# Episode: 0, Time step: 720
# Episode: 0, Time step: 750
# Episode: 0, Time step: 780
# Episode: 1, Time step: 0
# Episode: 1, Time step: 30
# Episode: 1, Time step: 60
# Episode: 1, Time step: 90
# Episode: 1, Time step: 120
# Episode: 1, Time step: 150
# Episode: 1, Time step: 180
# Episode: 1, Time step: 210
# Episode: 1, Time step: 240
# Episode: 1, Time step: 270
# Episode: 1, Time step: 300
# Episode: 1, Time step: 330
# Episode: 1, Time step: 360
# Episode: 1, Time step: 390
# Episode: 1, Time step: 420
# Episode: 1, Time step: 450
# Episode: 1, Time step: 480
# Episode: 1, Time step: 510
# Episode: 1, Time step: 540
# Episode: 1, Time step: 570
# Episode: 1, Time step: 600
# Episode: 1, Time step: 630
# Episode: 1, Time step: 660
# Episode: 1, Time step: 690
# Episode: 1, Time step: 720
# Episode: 1, Time step: 750
# Episode: 1, Time step: 780
# Episode: 2, Time step: 0
# Episode: 2, Time step: 30
# Episode: 2, Time step: 60
# Episode: 2, Time step: 90
# Episode: 2, Time step: 120
# Episode: 2, Time step: 150
# Episode: 2, Time step: 180
# Episode: 2, Time step: 210
# Episode: 2, Time step: 240
# Episode: 2, Time step: 270
# Episode: 2, Time step: 300
# Episode: 2, Time step: 330
# Episode: 2, Time step: 360
# Episode: 2, Time step: 390
# Episode: 2, Time step: 420
# Episode: 2, Time step: 450
# Episode: 2, Time step: 480
# Episode: 2, Time step: 510
# Episode: 2, Time step: 540
# Episode: 2, Time step: 570
# Episode: 2, Time step: 600
# Episode: 2, Time step: 630
# Episode: 2, Time step: 660
# Episode: 2, Time step: 690
# Episode: 2, Time step: 720
# Episode: 2, Time step: 750
# Episode: 2, Time step: 780
# Episode: 3, Time step: 0
# Episode: 3, Time step: 30
# Episode: 3, Time step: 60
# Episode: 3, Time step: 90
# Episode: 3, Time step: 120
# Episode: 3, Time step: 150
# Episode: 3, Time step: 180
# Episode: 3, Time step: 210
# Episode: 3, Time step: 240
# Episode: 3, Time step: 270
# Episode: 3, Time step: 300
# Episode: 3, Time step: 330
# Episode: 3, Time step: 360
# Episode: 3, Time step: 390
# Episode: 3, Time step: 420
# Episode: 3, Time step: 450
# Episode: 3, Time step: 480
# Episode: 3, Time step: 510
# Episode: 3, Time step: 540
# Episode: 3, Time step: 570
# Episode: 3, Time step: 600
# Episode: 3, Time step: 630
# Episode: 3, Time step: 660
# Episode: 3, Time step: 690
# Episode: 3, Time step: 720
# Episode: 3, Time step: 750
# Episode: 3, Time step: 780
# Episode: 4, Time step: 0
# Episode: 4, Time step: 30
# Episode: 4, Time step: 60
# Episode: 4, Time step: 90
# Episode: 4, Time step: 120
# Episode: 4, Time step: 150
# Episode: 4, Time step: 180
# Episode: 4, Time step: 210
# Episode: 4, Time step: 240
# Episode: 4, Time step: 270
# Episode: 4, Time step: 300
# Episode: 4, Time step: 330
# Episode: 4, Time step: 360
# Episode: 4, Time step: 390
# Episode: 4, Time step: 420
# Episode: 4, Time step: 450
# Episode: 4, Time step: 480
# Episode: 4, Time step: 510
# Episode: 4, Time step: 540
# Episode: 4, Time step: 570
# Episode: 4, Time step: 600
# Episode: 4, Time step: 630
# Episode: 4, Time step: 660
# Episode: 4, Time step: 690
# Episode: 4, Time step: 720
# Episode: 4, Time step: 750
# Episode: 4, Time step: 780
# Episode: 5, Time step: 0
# Episode: 5, Time step: 30
# Episode: 5, Time step: 60
# Episode: 5, Time step: 90
# Episode: 5, Time step: 120
# Episode: 5, Time step: 150
# Episode: 5, Time step: 180
# Episode: 5, Time step: 210
# Episode: 5, Time step: 240
# Episode: 5, Time step: 270
# Episode: 5, Time step: 300
# Episode: 5, Time step: 330
# Episode: 5, Time step: 360
# Episode: 5, Time step: 390
# Episode: 5, Time step: 420
# Episode: 5, Time step: 450
# Episode: 5, Time step: 480
# Episode: 5, Time step: 510
# Episode: 5, Time step: 540
# Episode: 5, Time step: 570
# Episode: 5, Time step: 600
# Episode: 5, Time step: 630
# Episode: 5, Time step: 660
# Episode: 5, Time step: 690
# Episode: 5, Time step: 720
# Episode: 5, Time step: 750
# Episode: 5, Time step: 780
# Episode: 6, Time step: 0
# Episode: 6, Time step: 30
# Episode: 6, Time step: 60
# Episode: 6, Time step: 90
# Episode: 6, Time step: 120
# Episode: 6, Time step: 150
# Episode: 6, Time step: 180
# Episode: 6, Time step: 210
# Episode: 6, Time step: 240
# Episode: 6, Time step: 270
# Episode: 6, Time step: 300
# Episode: 6, Time step: 330
# Episode: 6, Time step: 360
# Episode: 6, Time step: 390
# Episode: 6, Time step: 420
# Episode: 6, Time step: 450
# Episode: 6, Time step: 480
# Episode: 6, Time step: 510
# Episode: 6, Time step: 540
# Episode: 6, Time step: 570
# Episode: 6, Time step: 600
# Episode: 6, Time step: 630
# Episode: 6, Time step: 660
# Episode: 6, Time step: 690
# Episode: 6, Time step: 720
# Episode: 6, Time step: 750
# Episode: 6, Time step: 780
# Episode: 7, Time step: 0
# Episode: 7, Time step: 30
# Episode: 7, Time step: 60
# Episode: 7, Time step: 90
# Episode: 7, Time step: 120
# Episode: 7, Time step: 150
# Episode: 7, Time step: 180
# Episode: 7, Time step: 210
# Episode: 7, Time step: 240
# Episode: 7, Time step: 270
# Episode: 7, Time step: 300
# Episode: 7, Time step: 330
# Episode: 7, Time step: 360
# Episode: 7, Time step: 390
# Episode: 7, Time step: 420
# Episode: 7, Time step: 450
# Episode: 7, Time step: 480
# Episode: 7, Time step: 510
# Episode: 7, Time step: 540
# Episode: 7, Time step: 570
# Episode: 7, Time step: 600
# Episode: 7, Time step: 630
# Episode: 7, Time step: 660
# Episode: 7, Time step: 690
# Episode: 7, Time step: 720
# Episode: 7, Time step: 750
# Episode: 7, Time step: 780
# Episode: 8, Time step: 0
# Episode: 8, Time step: 30
# Episode: 8, Time step: 60
# Episode: 8, Time step: 90
# Episode: 8, Time step: 120
# Episode: 8, Time step: 150
# Episode: 8, Time step: 180
# Episode: 8, Time step: 210
# Episode: 8, Time step: 240
# Episode: 8, Time step: 270
# Episode: 8, Time step: 300
# Episode: 8, Time step: 330
# Episode: 8, Time step: 360
# Episode: 8, Time step: 390
# Episode: 8, Time step: 420
# Episode: 8, Time step: 450
# Episode: 8, Time step: 480
# Episode: 8, Time step: 510
# Episode: 8, Time step: 540
# Episode: 8, Time step: 570
# Episode: 8, Time step: 600
# Episode: 8, Time step: 630
# Episode: 8, Time step: 660
# Episode: 8, Time step: 690
# Episode: 8, Time step: 720
# Episode: 8, Time step: 750
# Episode: 8, Time step: 780
# Episode: 9, Time step: 0
# Episode: 9, Time step: 30
# Episode: 9, Time step: 60
# Episode: 9, Time step: 90
# Episode: 9, Time step: 120
# Episode: 9, Time step: 150
# Episode: 9, Time step: 180
# Episode: 9, Time step: 210
# Episode: 9, Time step: 240
# Episode: 9, Time step: 270
# Episode: 9, Time step: 300
# Episode: 9, Time step: 330
# Episode: 9, Time step: 360
# Episode: 9, Time step: 390
# Episode: 9, Time step: 420
# Episode: 9, Time step: 450
# Episode: 9, Time step: 480
# Episode: 9, Time step: 510
# Episode: 9, Time step: 540
# Episode: 9, Time step: 570
# Episode: 9, Time step: 600
# Episode: 9, Time step: 630
# Episode: 9, Time step: 660
# Episode: 9, Time step: 690
# Episode: 9, Time step: 720
# Episode: 9, Time step: 750
# Episode: 9, Time step: 780
# Episode: 10, Time step: 0
# Episode: 10, Time step: 30
# Episode: 10, Time step: 60
# Episode: 10, Time step: 90
# Episode: 10, Time step: 120
# Episode: 10, Time step: 150
# Episode: 10, Time step: 180
# Episode: 10, Time step: 210
# Episode: 10, Time step: 240
# Episode: 10, Time step: 270
# Episode: 10, Time step: 300
# Episode: 10, Time step: 330
# Episode: 10, Time step: 360
# Episode: 10, Time step: 390
# Episode: 10, Time step: 420
# Episode: 10, Time step: 450
# Episode: 10, Time step: 480
# Episode: 10, Time step: 510
# Episode: 10, Time step: 540
# Episode: 10, Time step: 570
# Episode: 10, Time step: 600
# Episode: 10, Time step: 630
# Episode: 10, Time step: 660
# Episode: 10, Time step: 690
# Episode: 10, Time step: 720
# Episode: 10, Time step: 750
# Episode: 10, Time step: 780
# Episode: 11, Time step: 0
# Episode: 11, Time step: 30
# Episode: 11, Time step: 60
# Episode: 11, Time step: 90
# Episode: 11, Time step: 120
# Episode: 11, Time step: 150
# Episode: 11, Time step: 180
# Episode: 11, Time step: 210
# Episode: 11, Time step: 240
# Episode: 11, Time step: 270
# Episode: 11, Time step: 300
# Episode: 11, Time step: 330
# Episode: 11, Time step: 360
# Episode: 11, Time step: 390
# Episode: 11, Time step: 420
# Episode: 11, Time step: 450
# Episode: 11, Time step: 480
# Episode: 11, Time step: 510
# Episode: 11, Time step: 540
# Episode: 11, Time step: 570
# Episode: 11, Time step: 600
# Episode: 11, Time step: 630
# Episode: 11, Time step: 660
# Episode: 11, Time step: 690
# Episode: 11, Time step: 720
# Episode: 11, Time step: 750
# Episode: 11, Time step: 780
# Episode: 12, Time step: 0
# Episode: 12, Time step: 30
# Episode: 12, Time step: 60
# Episode: 12, Time step: 90
# Episode: 12, Time step: 120
# Episode: 12, Time step: 150
# Episode: 12, Time step: 180
# Episode: 12, Time step: 210
# Episode: 12, Time step: 240
# Episode: 12, Time step: 270
# Episode: 12, Time step: 300
# Episode: 12, Time step: 330
# Episode: 12, Time step: 360
# Episode: 12, Time step: 390
# Episode: 12, Time step: 420
# Episode: 12, Time step: 450
# Episode: 12, Time step: 480
# Episode: 12, Time step: 510
# Episode: 12, Time step: 540
# Episode: 12, Time step: 570
# Episode: 12, Time step: 600
# Episode: 12, Time step: 630
# Episode: 12, Time step: 660
# Episode: 12, Time step: 690
# Episode: 12, Time step: 720
# Episode: 12, Time step: 750
# Episode: 12, Time step: 780
# Episode: 13, Time step: 0
# Episode: 13, Time step: 30
# Episode: 13, Time step: 60
# Episode: 13, Time step: 90
# Episode: 13, Time step: 120
# Episode: 13, Time step: 150
# Episode: 13, Time step: 180
# Episode: 13, Time step: 210
# Episode: 13, Time step: 240
# Episode: 13, Time step: 270
# Episode: 13, Time step: 300
# Episode: 13, Time step: 330
# Episode: 13, Time step: 360
# Episode: 13, Time step: 390
# Episode: 13, Time step: 420
# Episode: 13, Time step: 450
# Episode: 13, Time step: 480
# Episode: 13, Time step: 510
# Episode: 13, Time step: 540
# Episode: 13, Time step: 570
# Episode: 13, Time step: 600
# Episode: 13, Time step: 630
# Episode: 13, Time step: 660
# Episode: 13, Time step: 690
# Episode: 13, Time step: 720
# Episode: 13, Time step: 750
# Episode: 13, Time step: 780
# Episode: 14, Time step: 0
# Episode: 14, Time step: 30
# Episode: 14, Time step: 60
# Episode: 14, Time step: 90
# Episode: 14, Time step: 120
# Episode: 14, Time step: 150
# Episode: 14, Time step: 180
# Episode: 14, Time step: 210
# Episode: 14, Time step: 240
# Episode: 14, Time step: 270
# Episode: 14, Time step: 300
# Episode: 14, Time step: 330
# Episode: 14, Time step: 360
# Episode: 14, Time step: 390
# Episode: 14, Time step: 420
# Episode: 14, Time step: 450
# Episode: 14, Time step: 480
# Episode: 14, Time step: 510
# Episode: 14, Time step: 540
# Episode: 14, Time step: 570
# Episode: 14, Time step: 600
# Episode: 14, Time step: 630
# Episode: 14, Time step: 660
# Episode: 14, Time step: 690
# Episode: 14, Time step: 720
# Episode: 14, Time step: 750
# Episode: 14, Time step: 780
# Episode: 15, Time step: 0
# Episode: 15, Time step: 30
# Episode: 15, Time step: 60
# Episode: 15, Time step: 90
# Episode: 15, Time step: 120
# Episode: 15, Time step: 150
# Episode: 15, Time step: 180
# Episode: 15, Time step: 210
# Episode: 15, Time step: 240
# Episode: 15, Time step: 270
# Episode: 15, Time step: 300
# Episode: 15, Time step: 330
# Episode: 15, Time step: 360
# Episode: 15, Time step: 390
# Episode: 15, Time step: 420
# Episode: 15, Time step: 450
# Episode: 15, Time step: 480
# Episode: 15, Time step: 510
# Episode: 15, Time step: 540
# Episode: 15, Time step: 570
# Episode: 15, Time step: 600
# Episode: 15, Time step: 630
# Episode: 15, Time step: 660
# Episode: 15, Time step: 690
# Episode: 15, Time step: 720
# Episode: 15, Time step: 750
# Episode: 15, Time step: 780
# Episode: 16, Time step: 0
# Episode: 16, Time step: 30
# Episode: 16, Time step: 60
# Episode: 16, Time step: 90
# Episode: 16, Time step: 120
# Episode: 16, Time step: 150
# Episode: 16, Time step: 180
# Episode: 16, Time step: 210
# Episode: 16, Time step: 240
# Episode: 16, Time step: 270
# Episode: 16, Time step: 300
# Episode: 16, Time step: 330
# Episode: 16, Time step: 360
# Episode: 16, Time step: 390
# Episode: 16, Time step: 420
# Episode: 16, Time step: 450
# Episode: 16, Time step: 480
# Episode: 16, Time step: 510
# Episode: 16, Time step: 540
# Episode: 16, Time step: 570
# Episode: 16, Time step: 600
# Episode: 16, Time step: 630
# Episode: 16, Time step: 660
# Episode: 16, Time step: 690
# Episode: 16, Time step: 720
# Episode: 16, Time step: 750
# Episode: 16, Time step: 780
# Episode: 17, Time step: 0
# Episode: 17, Time step: 30
# Episode: 17, Time step: 60
# Episode: 17, Time step: 90
# Episode: 17, Time step: 120
# Episode: 17, Time step: 150
# Episode: 17, Time step: 180
# Episode: 17, Time step: 210
# Episode: 17, Time step: 240
# Episode: 17, Time step: 270
# Episode: 17, Time step: 300
# Episode: 17, Time step: 330
# Episode: 17, Time step: 360
# Episode: 17, Time step: 390
# Episode: 17, Time step: 420
# Episode: 17, Time step: 450
# Episode: 17, Time step: 480
# Episode: 17, Time step: 510
# Episode: 17, Time step: 540
# Episode: 17, Time step: 570
# Episode: 17, Time step: 600
# Episode: 17, Time step: 630
# Episode: 17, Time step: 660
# Episode: 17, Time step: 690
# Episode: 17, Time step: 720
# Episode: 17, Time step: 750
# Episode: 17, Time step: 780
# Episode: 18, Time step: 0
# Episode: 18, Time step: 30
# Episode: 18, Time step: 60
# Episode: 18, Time step: 90
# Episode: 18, Time step: 120
# Episode: 18, Time step: 150
# Episode: 18, Time step: 180
# Episode: 18, Time step: 210
# Episode: 18, Time step: 240
# Episode: 18, Time step: 270
# Episode: 18, Time step: 300
# Episode: 18, Time step: 330
# Episode: 18, Time step: 360
# Episode: 18, Time step: 390
# Episode: 18, Time step: 420
# Episode: 18, Time step: 450
# Episode: 18, Time step: 480
# Episode: 18, Time step: 510
# Episode: 18, Time step: 540
# Episode: 18, Time step: 570
# Episode: 18, Time step: 600
# Episode: 18, Time step: 630
# Episode: 18, Time step: 660
# Episode: 18, Time step: 690
# Episode: 18, Time step: 720
# Episode: 18, Time step: 750
# Episode: 18, Time step: 780
# Episode: 19, Time step: 0
# Episode: 19, Time step: 30
# Episode: 19, Time step: 60
# Episode: 19, Time step: 90
# Episode: 19, Time step: 120
# Episode: 19, Time step: 150
# Episode: 19, Time step: 180
# Episode: 19, Time step: 210
# Episode: 19, Time step: 240
# Episode: 19, Time step: 270
# Episode: 19, Time step: 300
# Episode: 19, Time step: 330
# Episode: 19, Time step: 360
# Episode: 19, Time step: 390
# Episode: 19, Time step: 420
# Episode: 19, Time step: 450
# Episode: 19, Time step: 480
# Episode: 19, Time step: 510
# Episode: 19, Time step: 540
# Episode: 19, Time step: 570
# Episode: 19, Time step: 600
# Episode: 19, Time step: 630
# Episode: 19, Time step: 660
# Episode: 19, Time step: 690
# Episode: 19, Time step: 720
# Episode: 19, Time step: 750
# Episode: 19, Time step: 780
# Episode: 20, Time step: 0
# Episode: 20, Time step: 30
# Episode: 20, Time step: 60
# Episode: 20, Time step: 90
# Episode: 20, Time step: 120
# Episode: 20, Time step: 150
# Episode: 20, Time step: 180
# Episode: 20, Time step: 210
# Episode: 20, Time step: 240
# Episode: 20, Time step: 270
# Episode: 20, Time step: 300
# Episode: 20, Time step: 330
# Episode: 20, Time step: 360
# Episode: 20, Time step: 390
# Episode: 20, Time step: 420
# Episode: 20, Time step: 450
# Episode: 20, Time step: 480
# Episode: 20, Time step: 510
# Episode: 20, Time step: 540
# Episode: 20, Time step: 570
# Episode: 20, Time step: 600
# Episode: 20, Time step: 630
# Episode: 20, Time step: 660
# Episode: 20, Time step: 690
# Episode: 20, Time step: 720
# Episode: 20, Time step: 750
# Episode: 20, Time step: 780
# Episode: 21, Time step: 0
# Episode: 21, Time step: 30
# Episode: 21, Time step: 60
# Episode: 21, Time step: 90
# Episode: 21, Time step: 120
# Episode: 21, Time step: 150
# Episode: 21, Time step: 180
# Episode: 21, Time step: 210
# Episode: 21, Time step: 240
# Episode: 21, Time step: 270
# Episode: 21, Time step: 300
# Episode: 21, Time step: 330
# Episode: 21, Time step: 360
# Episode: 21, Time step: 390
# Episode: 21, Time step: 420
# Episode: 21, Time step: 450
# Episode: 21, Time step: 480
# Episode: 21, Time step: 510
# Episode: 21, Time step: 540
# Episode: 21, Time step: 570
# Episode: 21, Time step: 600
# Episode: 21, Time step: 630
# Episode: 21, Time step: 660
# Episode: 21, Time step: 690
# Episode: 21, Time step: 720
# Episode: 21, Time step: 750
# Episode: 21, Time step: 780
# Episode: 22, Time step: 0
# Episode: 22, Time step: 30
# Episode: 22, Time step: 60
# Episode: 22, Time step: 90
# Episode: 22, Time step: 120
# Episode: 22, Time step: 150
# Episode: 22, Time step: 180
# Episode: 22, Time step: 210
# Episode: 22, Time step: 240
# Episode: 22, Time step: 270
# Episode: 22, Time step: 300
# Episode: 22, Time step: 330
# Episode: 22, Time step: 360
# Episode: 22, Time step: 390
# Episode: 22, Time step: 420
# Episode: 22, Time step: 450
# Episode: 22, Time step: 480
# Episode: 22, Time step: 510
# Episode: 22, Time step: 540
# Episode: 22, Time step: 570
# Episode: 22, Time step: 600
# Episode: 22, Time step: 630
# Episode: 22, Time step: 660
# Episode: 22, Time step: 690
# Episode: 22, Time step: 720
# Episode: 22, Time step: 750
# Episode: 22, Time step: 780
# Episode: 23, Time step: 0
# Episode: 23, Time step: 30
# Episode: 23, Time step: 60
# Episode: 23, Time step: 90
# Episode: 23, Time step: 120
# Episode: 23, Time step: 150
# Episode: 23, Time step: 180
# Episode: 23, Time step: 210
# Episode: 23, Time step: 240
# Episode: 23, Time step: 270
# Episode: 23, Time step: 300
# Episode: 23, Time step: 330
# Episode: 23, Time step: 360
# Episode: 23, Time step: 390
# Episode: 23, Time step: 420
# Episode: 23, Time step: 450
# Episode: 23, Time step: 480
# Episode: 23, Time step: 510
# Episode: 23, Time step: 540
# Episode: 23, Time step: 570
# Episode: 23, Time step: 600
# Episode: 23, Time step: 630
# Episode: 23, Time step: 660
# Episode: 23, Time step: 690
# Episode: 23, Time step: 720
# Episode: 23, Time step: 750
# Episode: 23, Time step: 780
# Episode: 24, Time step: 0
# Episode: 24, Time step: 30
# Episode: 24, Time step: 60
# Episode: 24, Time step: 90
# Episode: 24, Time step: 120
# Episode: 24, Time step: 150
# Episode: 24, Time step: 180
# Episode: 24, Time step: 210
# Episode: 24, Time step: 240
# Episode: 24, Time step: 270
# Episode: 24, Time step: 300
# Episode: 24, Time step: 330
# Episode: 24, Time step: 360
# Episode: 24, Time step: 390
# Episode: 24, Time step: 420
# Episode: 24, Time step: 450
# Episode: 24, Time step: 480
# Episode: 24, Time step: 510
# Episode: 24, Time step: 540
# Episode: 24, Time step: 570
# Episode: 24, Time step: 600
# Episode: 24, Time step: 630
# Episode: 24, Time step: 660
# Episode: 24, Time step: 690
# Episode: 24, Time step: 720
# Episode: 24, Time step: 750
# Episode: 24, Time step: 780
# Episode: 25, Time step: 0
# Episode: 25, Time step: 30
# Episode: 25, Time step: 60
# Episode: 25, Time step: 90
# Episode: 25, Time step: 120
# Episode: 25, Time step: 150
# Episode: 25, Time step: 180
# Episode: 25, Time step: 210
# Episode: 25, Time step: 240
# Episode: 25, Time step: 270
# Episode: 25, Time step: 300
# Episode: 25, Time step: 330
# Episode: 25, Time step: 360
# Episode: 25, Time step: 390
# Episode: 25, Time step: 420
# Episode: 25, Time step: 450
# Episode: 25, Time step: 480
# Episode: 25, Time step: 510
# Episode: 25, Time step: 540
# Episode: 25, Time step: 570
# Episode: 25, Time step: 600
# Episode: 25, Time step: 630
# Episode: 25, Time step: 660
# Episode: 25, Time step: 690
# Episode: 25, Time step: 720
# Episode: 25, Time step: 750
# Episode: 25, Time step: 780
# Episode: 26, Time step: 0
# Episode: 26, Time step: 30
# Episode: 26, Time step: 60
# Episode: 26, Time step: 90
# Episode: 26, Time step: 120
# Episode: 26, Time step: 150
# Episode: 26, Time step: 180
# Episode: 26, Time step: 210
# Episode: 26, Time step: 240
# Episode: 26, Time step: 270
# Episode: 26, Time step: 300
# Episode: 26, Time step: 330
# Episode: 26, Time step: 360
# Episode: 26, Time step: 390
# Episode: 26, Time step: 420
# Episode: 26, Time step: 450
# Episode: 26, Time step: 480
# Episode: 26, Time step: 510
# Episode: 26, Time step: 540
# Episode: 26, Time step: 570
# Episode: 26, Time step: 600
# Episode: 26, Time step: 630
# Episode: 26, Time step: 660
# Episode: 26, Time step: 690
# Episode: 26, Time step: 720
# Episode: 26, Time step: 750
# Episode: 26, Time step: 780
# Episode: 27, Time step: 0
# Episode: 27, Time step: 30
# Episode: 27, Time step: 60
# Episode: 27, Time step: 90
# Episode: 27, Time step: 120
# Episode: 27, Time step: 150
# Episode: 27, Time step: 180
# Episode: 27, Time step: 210
# Episode: 27, Time step: 240
# Episode: 27, Time step: 270
# Episode: 27, Time step: 300
# Episode: 27, Time step: 330
# Episode: 27, Time step: 360
# Episode: 27, Time step: 390
# Episode: 27, Time step: 420
# Episode: 27, Time step: 450
# Episode: 27, Time step: 480
# Episode: 27, Time step: 510
# Episode: 27, Time step: 540
# Episode: 27, Time step: 570
# Episode: 27, Time step: 600
# Episode: 27, Time step: 630
# Episode: 27, Time step: 660
# Episode: 27, Time step: 690
# Episode: 27, Time step: 720
# Episode: 27, Time step: 750
# Episode: 27, Time step: 780
# Episode: 28, Time step: 0
# Episode: 28, Time step: 30
# Episode: 28, Time step: 60
# Episode: 28, Time step: 90
# Episode: 28, Time step: 120
# Episode: 28, Time step: 150
# Episode: 28, Time step: 180
# Episode: 28, Time step: 210
# Episode: 28, Time step: 240
# Episode: 28, Time step: 270
# Episode: 28, Time step: 300
# Episode: 28, Time step: 330
# Episode: 28, Time step: 360
# Episode: 28, Time step: 390
# Episode: 28, Time step: 420
# Episode: 28, Time step: 450
# Episode: 28, Time step: 480
# Episode: 28, Time step: 510
# Episode: 28, Time step: 540
# Episode: 28, Time step: 570
# Episode: 28, Time step: 600
# Episode: 28, Time step: 630
# Episode: 28, Time step: 660
# Episode: 28, Time step: 690
# Episode: 28, Time step: 720
# Episode: 28, Time step: 750
# Episode: 28, Time step: 780
# Episode: 29, Time step: 0
# Episode: 29, Time step: 30
# Episode: 29, Time step: 60
# Episode: 29, Time step: 90
# Episode: 29, Time step: 120
# Episode: 29, Time step: 150
# Episode: 29, Time step: 180
# Episode: 29, Time step: 210
# Episode: 29, Time step: 240
# Episode: 29, Time step: 270
# Episode: 29, Time step: 300
# Episode: 29, Time step: 330
# Episode: 29, Time step: 360
# Episode: 29, Time step: 390
# Episode: 29, Time step: 420
# Episode: 29, Time step: 450
# Episode: 29, Time step: 480
# Episode: 29, Time step: 510
# Episode: 29, Time step: 540
# Episode: 29, Time step: 570
# Episode: 29, Time step: 600
# Episode: 29, Time step: 630
# Episode: 29, Time step: 660
# Episode: 29, Time step: 690
# Episode: 29, Time step: 720
# Episode: 29, Time step: 750
# Episode: 29, Time step: 780
# Episode: 30, Time step: 0
# Episode: 30, Time step: 30
# Episode: 30, Time step: 60
# Episode: 30, Time step: 90
# Episode: 30, Time step: 120
# Episode: 30, Time step: 150
# Episode: 30, Time step: 180
# Episode: 30, Time step: 210
# Episode: 30, Time step: 240
# Episode: 30, Time step: 270
# Episode: 30, Time step: 300
# Episode: 30, Time step: 330
# Episode: 30, Time step: 360
# Episode: 30, Time step: 390
# Episode: 30, Time step: 420
# Episode: 30, Time step: 450
# Episode: 30, Time step: 480
# Episode: 30, Time step: 510
# Episode: 30, Time step: 540
# Episode: 30, Time step: 570
# Episode: 30, Time step: 600
# Episode: 30, Time step: 630
# Episode: 30, Time step: 660
# Episode: 30, Time step: 690
# Episode: 30, Time step: 720
# Episode: 30, Time step: 750
# Episode: 30, Time step: 780
# Episode: 31, Time step: 0
# Episode: 31, Time step: 30
# Episode: 31, Time step: 60
# Episode: 31, Time step: 90
# Episode: 31, Time step: 120
# Episode: 31, Time step: 150
# Episode: 31, Time step: 180
# Episode: 31, Time step: 210
# Episode: 31, Time step: 240
# Episode: 31, Time step: 270
# Episode: 31, Time step: 300
# Episode: 31, Time step: 330
# Episode: 31, Time step: 360
# Episode: 31, Time step: 390
# Episode: 31, Time step: 420
# Episode: 31, Time step: 450
# Episode: 31, Time step: 480
# Episode: 31, Time step: 510
# Episode: 31, Time step: 540
# Episode: 31, Time step: 570
# Episode: 31, Time step: 600
# Episode: 31, Time step: 630
# Episode: 31, Time step: 660
# Episode: 31, Time step: 690
# Episode: 31, Time step: 720
# Episode: 31, Time step: 750
# Episode: 31, Time step: 780
# Episode: 32, Time step: 0
# Episode: 32, Time step: 30
# Episode: 32, Time step: 60
# Episode: 32, Time step: 90
# Episode: 32, Time step: 120
# Episode: 32, Time step: 150
# Episode: 32, Time step: 180
# Episode: 32, Time step: 210
# Episode: 32, Time step: 240
# Episode: 32, Time step: 270
# Episode: 32, Time step: 300
# Episode: 32, Time step: 330
# Episode: 32, Time step: 360
# Episode: 32, Time step: 390
# Episode: 32, Time step: 420
# Episode: 32, Time step: 450
# Episode: 32, Time step: 480
# Episode: 32, Time step: 510
# Episode: 32, Time step: 540
# Episode: 32, Time step: 570
# Episode: 32, Time step: 600
# Episode: 32, Time step: 630
# Episode: 32, Time step: 660
# Episode: 32, Time step: 690
# Episode: 32, Time step: 720
# Episode: 32, Time step: 750
# Episode: 32, Time step: 780
# Episode: 33, Time step: 0
# Episode: 33, Time step: 30
# Episode: 33, Time step: 60
# Episode: 33, Time step: 90
# Episode: 33, Time step: 120
# Episode: 33, Time step: 150
# Episode: 33, Time step: 180
# Episode: 33, Time step: 210
# Episode: 33, Time step: 240
# Episode: 33, Time step: 270
# Episode: 33, Time step: 300
# Episode: 33, Time step: 330
# Episode: 33, Time step: 360
# Episode: 33, Time step: 390
# Episode: 33, Time step: 420
# Episode: 33, Time step: 450
# Episode: 33, Time step: 480
# Episode: 33, Time step: 510
# Episode: 33, Time step: 540
# Episode: 33, Time step: 570
# Episode: 33, Time step: 600
# Episode: 33, Time step: 630
# Episode: 33, Time step: 660
# Episode: 33, Time step: 690
# Episode: 33, Time step: 720
# Episode: 33, Time step: 750
# Episode: 33, Time step: 780
# Episode: 34, Time step: 0
# Episode: 34, Time step: 30
# Episode: 34, Time step: 60
# Episode: 34, Time step: 90
# Episode: 34, Time step: 120
# Episode: 34, Time step: 150
# Episode: 34, Time step: 180
# Episode: 34, Time step: 210
# Episode: 34, Time step: 240
# Episode: 34, Time step: 270
# Episode: 34, Time step: 300
# Episode: 34, Time step: 330
# Episode: 34, Time step: 360
# Episode: 34, Time step: 390
# Episode: 34, Time step: 420
# Episode: 34, Time step: 450
# Episode: 34, Time step: 480
# Episode: 34, Time step: 510
# Episode: 34, Time step: 540
# Episode: 34, Time step: 570
# Episode: 34, Time step: 600
# Episode: 34, Time step: 630
# Episode: 34, Time step: 660
# Episode: 34, Time step: 690
# Episode: 34, Time step: 720
# Episode: 34, Time step: 750
# Episode: 34, Time step: 780
# Episode: 35, Time step: 0
# Episode: 35, Time step: 30
# Episode: 35, Time step: 60
# Episode: 35, Time step: 90
# Episode: 35, Time step: 120
# Episode: 35, Time step: 150
# Episode: 35, Time step: 180
# Episode: 35, Time step: 210
# Episode: 35, Time step: 240
# Episode: 35, Time step: 270
# Episode: 35, Time step: 300
# Episode: 35, Time step: 330
# Episode: 35, Time step: 360
# Episode: 35, Time step: 390
# Episode: 35, Time step: 420
# Episode: 35, Time step: 450
# Episode: 35, Time step: 480
# Episode: 35, Time step: 510
# Episode: 35, Time step: 540
# Episode: 35, Time step: 570
# Episode: 35, Time step: 600
# Episode: 35, Time step: 630
# Episode: 35, Time step: 660
# Episode: 35, Time step: 690
# Episode: 35, Time step: 720
# Episode: 35, Time step: 750
# Episode: 35, Time step: 780
# Episode: 36, Time step: 0
# Episode: 36, Time step: 30
# Episode: 36, Time step: 60
# Episode: 36, Time step: 90
# Episode: 36, Time step: 120
# Episode: 36, Time step: 150
# Episode: 36, Time step: 180
# Episode: 36, Time step: 210
# Episode: 36, Time step: 240
# Episode: 36, Time step: 270
# Episode: 36, Time step: 300
# Episode: 36, Time step: 330
# Episode: 36, Time step: 360
# Episode: 36, Time step: 390
# Episode: 36, Time step: 420
# Episode: 36, Time step: 450
# Episode: 36, Time step: 480
# Episode: 36, Time step: 510
# Episode: 36, Time step: 540
# Episode: 36, Time step: 570
# Episode: 36, Time step: 600
# Episode: 36, Time step: 630
# Episode: 36, Time step: 660
# Episode: 36, Time step: 690
# Episode: 36, Time step: 720
# Episode: 36, Time step: 750
# Episode: 36, Time step: 780
# Episode: 37, Time step: 0
# Episode: 37, Time step: 30
# Episode: 37, Time step: 60
# Episode: 37, Time step: 90
# Episode: 37, Time step: 120
# Episode: 37, Time step: 150
# Episode: 37, Time step: 180
# Episode: 37, Time step: 210
# Episode: 37, Time step: 240
# Episode: 37, Time step: 270
# Episode: 37, Time step: 300
# Episode: 37, Time step: 330
# Episode: 37, Time step: 360
# Episode: 37, Time step: 390
# Episode: 37, Time step: 420
# Episode: 37, Time step: 450
# Episode: 37, Time step: 480
# Episode: 37, Time step: 510
# Episode: 37, Time step: 540
# Episode: 37, Time step: 570
# Episode: 37, Time step: 600
# Episode: 37, Time step: 630
# Episode: 37, Time step: 660
# Episode: 37, Time step: 690
# Episode: 37, Time step: 720
# Episode: 37, Time step: 750
# Episode: 37, Time step: 780
# Episode: 38, Time step: 0
# Episode: 38, Time step: 30
# Episode: 38, Time step: 60
# Episode: 38, Time step: 90
# Episode: 38, Time step: 120
# Episode: 38, Time step: 150
# Episode: 38, Time step: 180
# Episode: 38, Time step: 210
# Episode: 38, Time step: 240
# Episode: 38, Time step: 270
# Episode: 38, Time step: 300
# Episode: 38, Time step: 330
# Episode: 38, Time step: 360
# Episode: 38, Time step: 390
# Episode: 38, Time step: 420
# Episode: 38, Time step: 450
# Episode: 38, Time step: 480
# Episode: 38, Time step: 510
# Episode: 38, Time step: 540
# Episode: 38, Time step: 570
# Episode: 38, Time step: 600
# Episode: 38, Time step: 630
# Episode: 38, Time step: 660
# Episode: 38, Time step: 690
# Episode: 38, Time step: 720
# Episode: 38, Time step: 750
# Episode: 38, Time step: 780
# Episode: 39, Time step: 0
# Episode: 39, Time step: 30
# Episode: 39, Time step: 60
# Episode: 39, Time step: 90
# Episode: 39, Time step: 120
# Episode: 39, Time step: 150
# Episode: 39, Time step: 180
# Episode: 39, Time step: 210
# Episode: 39, Time step: 240
# Episode: 39, Time step: 270
# Episode: 39, Time step: 300
# Episode: 39, Time step: 330
# Episode: 39, Time step: 360
# Episode: 39, Time step: 390
# Episode: 39, Time step: 420
# Episode: 39, Time step: 450
# Episode: 39, Time step: 480
# Episode: 39, Time step: 510
# Episode: 39, Time step: 540
# Episode: 39, Time step: 570
# Episode: 39, Time step: 600
# Episode: 39, Time step: 630
# Episode: 39, Time step: 660
# Episode: 39, Time step: 690
# Episode: 39, Time step: 720
# Episode: 39, Time step: 750
# Episode: 39, Time step: 780
# Episode: 40, Time step: 0
# Episode: 40, Time step: 30
# Episode: 40, Time step: 60
# Episode: 40, Time step: 90
# Episode: 40, Time step: 120
# Episode: 40, Time step: 150
# Episode: 40, Time step: 180
# Episode: 40, Time step: 210
# Episode: 40, Time step: 240
# Episode: 40, Time step: 270
# Episode: 40, Time step: 300
# Episode: 40, Time step: 330
# Episode: 40, Time step: 360
# Episode: 40, Time step: 390
# Episode: 40, Time step: 420
# Episode: 40, Time step: 450
# Episode: 40, Time step: 480
# Episode: 40, Time step: 510
# Episode: 40, Time step: 540
# Episode: 40, Time step: 570
# Episode: 40, Time step: 600
# Episode: 40, Time step: 630
# Episode: 40, Time step: 660
# Episode: 40, Time step: 690
# Episode: 40, Time step: 720
# Episode: 40, Time step: 750
# Episode: 40, Time step: 780
# Episode: 41, Time step: 0
# Episode: 41, Time step: 30
# Episode: 41, Time step: 60
# Episode: 41, Time step: 90
# Episode: 41, Time step: 120
# Episode: 41, Time step: 150
# Episode: 41, Time step: 180
# Episode: 41, Time step: 210
# Episode: 41, Time step: 240
# Episode: 41, Time step: 270
# Episode: 41, Time step: 300
# Episode: 41, Time step: 330
# Episode: 41, Time step: 360
# Episode: 41, Time step: 390
# Episode: 41, Time step: 420
# Episode: 41, Time step: 450
# Episode: 41, Time step: 480
# Episode: 41, Time step: 510
# Episode: 41, Time step: 540
# Episode: 41, Time step: 570
# Episode: 41, Time step: 600
# Episode: 41, Time step: 630
# Episode: 41, Time step: 660
# Episode: 41, Time step: 690
# Episode: 41, Time step: 720
# Episode: 41, Time step: 750
# Episode: 41, Time step: 780
# Episode: 42, Time step: 0
# Episode: 42, Time step: 30
# Episode: 42, Time step: 60
# Episode: 42, Time step: 90
# Episode: 42, Time step: 120
# Episode: 42, Time step: 150
# Episode: 42, Time step: 180
# Episode: 42, Time step: 210
# Episode: 42, Time step: 240
# Episode: 42, Time step: 270
# Episode: 42, Time step: 300
# Episode: 42, Time step: 330
# Episode: 42, Time step: 360
# Episode: 42, Time step: 390
# Episode: 42, Time step: 420
# Episode: 42, Time step: 450
# Episode: 42, Time step: 480
# Episode: 42, Time step: 510
# Episode: 42, Time step: 540
# Episode: 42, Time step: 570
# Episode: 42, Time step: 600
# Episode: 42, Time step: 630
# Episode: 42, Time step: 660
# Episode: 42, Time step: 690
# Episode: 42, Time step: 720
# Episode: 42, Time step: 750
# Episode: 42, Time step: 780
# Episode: 43, Time step: 0
# Episode: 43, Time step: 30
# Episode: 43, Time step: 60
# Episode: 43, Time step: 90
# Episode: 43, Time step: 120
# Episode: 43, Time step: 150
# Episode: 43, Time step: 180
# Episode: 43, Time step: 210
# Episode: 43, Time step: 240
# Episode: 43, Time step: 270
# Episode: 43, Time step: 300
# Episode: 43, Time step: 330
# Episode: 43, Time step: 360
# Episode: 43, Time step: 390
# Episode: 43, Time step: 420
# Episode: 43, Time step: 450
# Episode: 43, Time step: 480
# Episode: 43, Time step: 510
# Episode: 43, Time step: 540
# Episode: 43, Time step: 570
# Episode: 43, Time step: 600
# Episode: 43, Time step: 630
# Episode: 43, Time step: 660
# Episode: 43, Time step: 690
# Episode: 43, Time step: 720
# Episode: 43, Time step: 750
# Episode: 43, Time step: 780
# Episode: 44, Time step: 0
# Episode: 44, Time step: 30
# Episode: 44, Time step: 60
# Episode: 44, Time step: 90
# Episode: 44, Time step: 120
# Episode: 44, Time step: 150
# Episode: 44, Time step: 180
# Episode: 44, Time step: 210
# Episode: 44, Time step: 240
# Episode: 44, Time step: 270
# Episode: 44, Time step: 300
# Episode: 44, Time step: 330
# Episode: 44, Time step: 360
# Episode: 44, Time step: 390
# Episode: 44, Time step: 420
# Episode: 44, Time step: 450
# Episode: 44, Time step: 480
# Episode: 44, Time step: 510
# Episode: 44, Time step: 540
# Episode: 44, Time step: 570
# Episode: 44, Time step: 600
# Episode: 44, Time step: 630
# Episode: 44, Time step: 660
# Episode: 44, Time step: 690
# Episode: 44, Time step: 720
# Episode: 44, Time step: 750
# Episode: 44, Time step: 780
# Episode: 45, Time step: 0
# Episode: 45, Time step: 30
# Episode: 45, Time step: 60
# Episode: 45, Time step: 90
# Episode: 45, Time step: 120
# Episode: 45, Time step: 150
# Episode: 45, Time step: 180
# Episode: 45, Time step: 210
# Episode: 45, Time step: 240
# Episode: 45, Time step: 270
# Episode: 45, Time step: 300
# Episode: 45, Time step: 330
# Episode: 45, Time step: 360
# Episode: 45, Time step: 390
# Episode: 45, Time step: 420
# Episode: 45, Time step: 450
# Episode: 45, Time step: 480
# Episode: 45, Time step: 510
# Episode: 45, Time step: 540
# Episode: 45, Time step: 570
# Episode: 45, Time step: 600
# Episode: 45, Time step: 630
# Episode: 45, Time step: 660
# Episode: 45, Time step: 690
# Episode: 45, Time step: 720
# Episode: 45, Time step: 750
# Episode: 45, Time step: 780
# Episode: 46, Time step: 0
# Episode: 46, Time step: 30
# Episode: 46, Time step: 60
# Episode: 46, Time step: 90
# Episode: 46, Time step: 120
# Episode: 46, Time step: 150
# Episode: 46, Time step: 180
# Episode: 46, Time step: 210
# Episode: 46, Time step: 240
# Episode: 46, Time step: 270
# Episode: 46, Time step: 300
# Episode: 46, Time step: 330
# Episode: 46, Time step: 360
# Episode: 46, Time step: 390
# Episode: 46, Time step: 420
# Episode: 46, Time step: 450
# Episode: 46, Time step: 480
# Episode: 46, Time step: 510
# Episode: 46, Time step: 540
# Episode: 46, Time step: 570
# Episode: 46, Time step: 600
# Episode: 46, Time step: 630
# Episode: 46, Time step: 660
# Episode: 46, Time step: 690
# Episode: 46, Time step: 720
# Episode: 46, Time step: 750
# Episode: 46, Time step: 780
# Episode: 47, Time step: 0
# Episode: 47, Time step: 30
# Episode: 47, Time step: 60
# Episode: 47, Time step: 90
# Episode: 47, Time step: 120
# Episode: 47, Time step: 150
# Episode: 47, Time step: 180
# Episode: 47, Time step: 210
# Episode: 47, Time step: 240
# Episode: 47, Time step: 270
# Episode: 47, Time step: 300
# Episode: 47, Time step: 330
# Episode: 47, Time step: 360
# Episode: 47, Time step: 390
# Episode: 47, Time step: 420
# Episode: 47, Time step: 450
# Episode: 47, Time step: 480
# Episode: 47, Time step: 510
# Episode: 47, Time step: 540
# Episode: 47, Time step: 570
# Episode: 47, Time step: 600
# Episode: 47, Time step: 630
# Episode: 47, Time step: 660
# Episode: 47, Time step: 690
# Episode: 47, Time step: 720
# Episode: 47, Time step: 750
# Episode: 47, Time step: 780
# Episode: 48, Time step: 0
# Episode: 48, Time step: 30
# Episode: 48, Time step: 60
# Episode: 48, Time step: 90
# Episode: 48, Time step: 120
# Episode: 48, Time step: 150
# Episode: 48, Time step: 180
# Episode: 48, Time step: 210
# Episode: 48, Time step: 240
# Episode: 48, Time step: 270
# Episode: 48, Time step: 300
# Episode: 48, Time step: 330
# Episode: 48, Time step: 360
# Episode: 48, Time step: 390
# Episode: 48, Time step: 420
# Episode: 48, Time step: 450
# Episode: 48, Time step: 480
# Episode: 48, Time step: 510
# Episode: 48, Time step: 540
# Episode: 48, Time step: 570
# Episode: 48, Time step: 600
# Episode: 48, Time step: 630
# Episode: 48, Time step: 660
# Episode: 48, Time step: 690
# Episode: 48, Time step: 720
# Episode: 48, Time step: 750
# Episode: 48, Time step: 780
# Episode: 49, Time step: 0
# Episode: 49, Time step: 30
# Episode: 49, Time step: 60
# Episode: 49, Time step: 90
# Episode: 49, Time step: 120
# Episode: 49, Time step: 150
# Episode: 49, Time step: 180
# Episode: 49, Time step: 210
# Episode: 49, Time step: 240
# Episode: 49, Time step: 270
# Episode: 49, Time step: 300
# Episode: 49, Time step: 330
# Episode: 49, Time step: 360
# Episode: 49, Time step: 390
# Episode: 49, Time step: 420
# Episode: 49, Time step: 450
# Episode: 49, Time step: 480
# Episode: 49, Time step: 510
# Episode: 49, Time step: 540
# Episode: 49, Time step: 570
# Episode: 49, Time step: 600
# Episode: 49, Time step: 630
# Episode: 49, Time step: 660
# Episode: 49, Time step: 690
# Episode: 49, Time step: 720
# Episode: 49, Time step: 750
# Episode: 49, Time step: 780
# Episode: 50, Time step: 0
# Episode: 50, Time step: 30
# Episode: 50, Time step: 60
# Episode: 50, Time step: 90
# Episode: 50, Time step: 120
# Episode: 50, Time step: 150
# Episode: 50, Time step: 180
# Episode: 50, Time step: 210
# Episode: 50, Time step: 240
# Episode: 50, Time step: 270
# Episode: 50, Time step: 300
# Episode: 50, Time step: 330
# Episode: 50, Time step: 360
# Episode: 50, Time step: 390
# Episode: 50, Time step: 420
# Episode: 50, Time step: 450
# Episode: 50, Time step: 480
# Episode: 50, Time step: 510
# Episode: 50, Time step: 540
# Episode: 50, Time step: 570
# Episode: 50, Time step: 600
# Episode: 50, Time step: 630
# Episode: 50, Time step: 660
# Episode: 50, Time step: 690
# Episode: 50, Time step: 720
# Episode: 50, Time step: 750
# Episode: 50, Time step: 780
# Episode: 51, Time step: 0
# Episode: 51, Time step: 30
# Episode: 51, Time step: 60
# Episode: 51, Time step: 90
# Episode: 51, Time step: 120
# Episode: 51, Time step: 150
# Episode: 51, Time step: 180
# Episode: 51, Time step: 210
# Episode: 51, Time step: 240
# Episode: 51, Time step: 270
# Episode: 51, Time step: 300
# Episode: 51, Time step: 330
# Episode: 51, Time step: 360
# Episode: 51, Time step: 390
# Episode: 51, Time step: 420
# Episode: 51, Time step: 450
# Episode: 51, Time step: 480
# Episode: 51, Time step: 510
# Episode: 51, Time step: 540
# Episode: 51, Time step: 570
# Episode: 51, Time step: 600
# Episode: 51, Time step: 630
# Episode: 51, Time step: 660
# Episode: 51, Time step: 690
# Episode: 51, Time step: 720
# Episode: 51, Time step: 750
# Episode: 51, Time step: 780
# Episode: 52, Time step: 0
# Episode: 52, Time step: 30
# Episode: 52, Time step: 60
# Episode: 52, Time step: 90
# Episode: 52, Time step: 120
# Episode: 52, Time step: 150
# Episode: 52, Time step: 180
# Episode: 52, Time step: 210
# Episode: 52, Time step: 240
# Episode: 52, Time step: 270
# Episode: 52, Time step: 300
# Episode: 52, Time step: 330
# Episode: 52, Time step: 360
# Episode: 52, Time step: 390
# Episode: 52, Time step: 420
# Episode: 52, Time step: 450
# Episode: 52, Time step: 480
# Episode: 52, Time step: 510
# Episode: 52, Time step: 540
# Episode: 52, Time step: 570
# Episode: 52, Time step: 600
# Episode: 52, Time step: 630
# Episode: 52, Time step: 660
# Episode: 52, Time step: 690
# Episode: 52, Time step: 720
# Episode: 52, Time step: 750
# Episode: 52, Time step: 780
# Episode: 53, Time step: 0
# Episode: 53, Time step: 30
# Episode: 53, Time step: 60
# Episode: 53, Time step: 90
# Episode: 53, Time step: 120
# Episode: 53, Time step: 150
# Episode: 53, Time step: 180
# Episode: 53, Time step: 210
# Episode: 53, Time step: 240
# Episode: 53, Time step: 270
# Episode: 53, Time step: 300
# Episode: 53, Time step: 330
# Episode: 53, Time step: 360
# Episode: 53, Time step: 390
# Episode: 53, Time step: 420
# Episode: 53, Time step: 450
# Episode: 53, Time step: 480
# Episode: 53, Time step: 510
# Episode: 53, Time step: 540
# Episode: 53, Time step: 570
# Episode: 53, Time step: 600
# Episode: 53, Time step: 630
# Episode: 53, Time step: 660
# Episode: 53, Time step: 690
# Episode: 53, Time step: 720
# Episode: 53, Time step: 750
# Episode: 53, Time step: 780
# Episode: 54, Time step: 0
# Episode: 54, Time step: 30
# Episode: 54, Time step: 60
# Episode: 54, Time step: 90
# Episode: 54, Time step: 120
# Episode: 54, Time step: 150
# Episode: 54, Time step: 180
# Episode: 54, Time step: 210
# Episode: 54, Time step: 240
# Episode: 54, Time step: 270
# Episode: 54, Time step: 300
# Episode: 54, Time step: 330
# Episode: 54, Time step: 360
# Episode: 54, Time step: 390
# Episode: 54, Time step: 420
# Episode: 54, Time step: 450
# Episode: 54, Time step: 480
# Episode: 54, Time step: 510
# Episode: 54, Time step: 540
# Episode: 54, Time step: 570
# Episode: 54, Time step: 600
# Episode: 54, Time step: 630
# Episode: 54, Time step: 660
# Episode: 54, Time step: 690
# Episode: 54, Time step: 720
# Episode: 54, Time step: 750
# Episode: 54, Time step: 780
# Episode: 55, Time step: 0
# Episode: 55, Time step: 30
# Episode: 55, Time step: 60
# Episode: 55, Time step: 90
# Episode: 55, Time step: 120
# Episode: 55, Time step: 150
# Episode: 55, Time step: 180
# Episode: 55, Time step: 210
# Episode: 55, Time step: 240
# Episode: 55, Time step: 270
# Episode: 55, Time step: 300
# Episode: 55, Time step: 330
# Episode: 55, Time step: 360
# Episode: 55, Time step: 390
# Episode: 55, Time step: 420
# Episode: 55, Time step: 450
# Episode: 55, Time step: 480
# Episode: 55, Time step: 510
# Episode: 55, Time step: 540
# Episode: 55, Time step: 570
# Episode: 55, Time step: 600
# Episode: 55, Time step: 630
# Episode: 55, Time step: 660
# Episode: 55, Time step: 690
# Episode: 55, Time step: 720
# Episode: 55, Time step: 750
# Episode: 55, Time step: 780
# Episode: 56, Time step: 0
# Episode: 56, Time step: 30
# Episode: 56, Time step: 60
# Episode: 56, Time step: 90
# Episode: 56, Time step: 120
# Episode: 56, Time step: 150
# Episode: 56, Time step: 180
# Episode: 56, Time step: 210
# Episode: 56, Time step: 240
# Episode: 56, Time step: 270
# Episode: 56, Time step: 300
# Episode: 56, Time step: 330
# Episode: 56, Time step: 360
# Episode: 56, Time step: 390
# Episode: 56, Time step: 420
# Episode: 56, Time step: 450
# Episode: 56, Time step: 480
# Episode: 56, Time step: 510
# Episode: 56, Time step: 540
# Episode: 56, Time step: 570
# Episode: 56, Time step: 600
# Episode: 56, Time step: 630
# Episode: 56, Time step: 660
# Episode: 56, Time step: 690
# Episode: 56, Time step: 720
# Episode: 56, Time step: 750
# Episode: 56, Time step: 780
# Episode: 57, Time step: 0
# Episode: 57, Time step: 30
# Episode: 57, Time step: 60
# Episode: 57, Time step: 90
# Episode: 57, Time step: 120
# Episode: 57, Time step: 150
# Episode: 57, Time step: 180
# Episode: 57, Time step: 210
# Episode: 57, Time step: 240
# Episode: 57, Time step: 270
# Episode: 57, Time step: 300
# Episode: 57, Time step: 330
# Episode: 57, Time step: 360
# Episode: 57, Time step: 390
# Episode: 57, Time step: 420
# Episode: 57, Time step: 450
# Episode: 57, Time step: 480
# Episode: 57, Time step: 510
# Episode: 57, Time step: 540
# Episode: 57, Time step: 570
# Episode: 57, Time step: 600
# Episode: 57, Time step: 630
# Episode: 57, Time step: 660
# Episode: 57, Time step: 690
# Episode: 57, Time step: 720
# Episode: 57, Time step: 750
# Episode: 57, Time step: 780
# Episode: 58, Time step: 0
# Episode: 58, Time step: 30
# Episode: 58, Time step: 60
# Episode: 58, Time step: 90
# Episode: 58, Time step: 120
# Episode: 58, Time step: 150
# Episode: 58, Time step: 180
# Episode: 58, Time step: 210
# Episode: 58, Time step: 240
# Episode: 58, Time step: 270
# Episode: 58, Time step: 300
# Episode: 58, Time step: 330
# Episode: 58, Time step: 360
# Episode: 58, Time step: 390
# Episode: 58, Time step: 420
# Episode: 58, Time step: 450
# Episode: 58, Time step: 480
# Episode: 58, Time step: 510
# Episode: 58, Time step: 540
# Episode: 58, Time step: 570
# Episode: 58, Time step: 600
# Episode: 58, Time step: 630
# Episode: 58, Time step: 660
# Episode: 58, Time step: 690
# Episode: 58, Time step: 720
# Episode: 58, Time step: 750
# Episode: 58, Time step: 780
# Episode: 59, Time step: 0
# Episode: 59, Time step: 30
# Episode: 59, Time step: 60
# Episode: 59, Time step: 90
# Episode: 59, Time step: 120
# Episode: 59, Time step: 150
# Episode: 59, Time step: 180
# Episode: 59, Time step: 210
# Episode: 59, Time step: 240
# Episode: 59, Time step: 270
# Episode: 59, Time step: 300
# Episode: 59, Time step: 330
# Episode: 59, Time step: 360
# Episode: 59, Time step: 390
# Episode: 59, Time step: 420
# Episode: 59, Time step: 450
# Episode: 59, Time step: 480
# Episode: 59, Time step: 510
# Episode: 59, Time step: 540
# Episode: 59, Time step: 570
# Episode: 59, Time step: 600
# Episode: 59, Time step: 630
# Episode: 59, Time step: 660
# Episode: 59, Time step: 690
# Episode: 59, Time step: 720
# Episode: 59, Time step: 750
# Episode: 59, Time step: 780
# Episode: 60, Time step: 0
# Episode: 60, Time step: 30
# Episode: 60, Time step: 60
# Episode: 60, Time step: 90
# Episode: 60, Time step: 120
# Episode: 60, Time step: 150
# Episode: 60, Time step: 180
# Episode: 60, Time step: 210
# Episode: 60, Time step: 240
# Episode: 60, Time step: 270
# Episode: 60, Time step: 300
# Episode: 60, Time step: 330
# Episode: 60, Time step: 360
# Episode: 60, Time step: 390
# Episode: 60, Time step: 420
# Episode: 60, Time step: 450
# Episode: 60, Time step: 480
# Episode: 60, Time step: 510
# Episode: 60, Time step: 540
# Episode: 60, Time step: 570
# Episode: 60, Time step: 600
# Episode: 60, Time step: 630
# Episode: 60, Time step: 660
# Episode: 60, Time step: 690
# Episode: 60, Time step: 720
# Episode: 60, Time step: 750
# Episode: 60, Time step: 780
# Episode: 61, Time step: 0
# Episode: 61, Time step: 30
# Episode: 61, Time step: 60
# Episode: 61, Time step: 90
# Episode: 61, Time step: 120
# Episode: 61, Time step: 150
# Episode: 61, Time step: 180
# Episode: 61, Time step: 210
# Episode: 61, Time step: 240
# Episode: 61, Time step: 270
# Episode: 61, Time step: 300
# Episode: 61, Time step: 330
# Episode: 61, Time step: 360
# Episode: 61, Time step: 390
# Episode: 61, Time step: 420
# Episode: 61, Time step: 450
# Episode: 61, Time step: 480
# Episode: 61, Time step: 510
# Episode: 61, Time step: 540
# Episode: 61, Time step: 570
# Episode: 61, Time step: 600
# Episode: 61, Time step: 630
# Episode: 61, Time step: 660
# Episode: 61, Time step: 690
# Episode: 61, Time step: 720
# Episode: 61, Time step: 750
# Episode: 61, Time step: 780
# Episode: 62, Time step: 0
# Episode: 62, Time step: 30
# Episode: 62, Time step: 60
# Episode: 62, Time step: 90
# Episode: 62, Time step: 120
# Episode: 62, Time step: 150
# Episode: 62, Time step: 180
# Episode: 62, Time step: 210
# Episode: 62, Time step: 240
# Episode: 62, Time step: 270
# Episode: 62, Time step: 300
# Episode: 62, Time step: 330
# Episode: 62, Time step: 360
# Episode: 62, Time step: 390
# Episode: 62, Time step: 420
# Episode: 62, Time step: 450
# Episode: 62, Time step: 480
# Episode: 62, Time step: 510
# Episode: 62, Time step: 540
# Episode: 62, Time step: 570
# Episode: 62, Time step: 600
# Episode: 62, Time step: 630
# Episode: 62, Time step: 660
# Episode: 62, Time step: 690
# Episode: 62, Time step: 720
# Episode: 62, Time step: 750
# Episode: 62, Time step: 780
# Episode: 63, Time step: 0
# Episode: 63, Time step: 30
# Episode: 63, Time step: 60
# Episode: 63, Time step: 90
# Episode: 63, Time step: 120
# Episode: 63, Time step: 150
# Episode: 63, Time step: 180
# Episode: 63, Time step: 210
# Episode: 63, Time step: 240
# Episode: 63, Time step: 270
# Episode: 63, Time step: 300
# Episode: 63, Time step: 330
# Episode: 63, Time step: 360
# Episode: 63, Time step: 390
# Episode: 63, Time step: 420
# Episode: 63, Time step: 450
# Episode: 63, Time step: 480
# Episode: 63, Time step: 510
# Episode: 63, Time step: 540
# Episode: 63, Time step: 570
# Episode: 63, Time step: 600
# Episode: 63, Time step: 630
# Episode: 63, Time step: 660
# Episode: 63, Time step: 690
# Episode: 63, Time step: 720
# Episode: 63, Time step: 750
# Episode: 63, Time step: 780
# Episode: 64, Time step: 0
# Episode: 64, Time step: 30
# Episode: 64, Time step: 60
# Episode: 64, Time step: 90
# Episode: 64, Time step: 120
# Episode: 64, Time step: 150
# Episode: 64, Time step: 180
# ...
# Episode: 178, Time step: 450
# Episode: 178, Time step: 480
# Episode: 178, Time step: 510
# Episode: 178, Time step: 540
# Episode: 178, Time step: 570
# Episode: 178, Time step: 600
# Episode: 178, Time step: 630
# Episode: 178, Time step: 660
# Episode: 178, Time step: 690
# Episode: 178, Time step: 720
# Episode: 178, Time step: 750
# Episode: 178, Time step: 780
# Episode: 179, Time step: 0
# Episode: 179, Time step: 30
# Episode: 179, Time step: 60
# Episode: 179, Time step: 90
# Episode: 179, Time step: 120
# Episode: 179, Time step: 150
# Episode: 179, Time step: 180
# Episode: 179, Time step: 210
# Episode: 179, Time step: 240
# Episode: 179, Time step: 270
# Episode: 179, Time step: 300
# Episode: 179, Time step: 330
# Episode: 179, Time step: 360
# Episode: 179, Time step: 390
# Episode: 179, Time step: 420
# Episode: 179, Time step: 450
# Episode: 179, Time step: 480
# Episode: 179, Time step: 510
# Episode: 179, Time step: 540
# Episode: 179, Time step: 570
# Episode: 179, Time step: 600
# Episode: 179, Time step: 630
# Episode: 179, Time step: 660
# Episode: 179, Time step: 690
# Episode: 179, Time step: 720
# Episode: 179, Time step: 750
# Episode: 179, Time step: 780
# Episode: 180, Time step: 0
# Episode: 180, Time step: 30
# Episode: 180, Time step: 60
# Episode: 180, Time step: 90
# Episode: 180, Time step: 120
# Episode: 180, Time step: 150
# Episode: 180, Time step: 180
# Episode: 180, Time step: 210
# Episode: 180, Time step: 240
# Episode: 180, Time step: 270
# Episode: 180, Time step: 300
# Episode: 180, Time step: 330
# Episode: 180, Time step: 360
# Episode: 180, Time step: 390
# Episode: 180, Time step: 420
# Episode: 180, Time step: 450
# Episode: 180, Time step: 480
# Episode: 180, Time step: 510
# Episode: 180, Time step: 540
# Episode: 180, Time step: 570
# Episode: 180, Time step: 600
# Episode: 180, Time step: 630
# Episode: 180, Time step: 660
# Episode: 180, Time step: 690
# Episode: 180, Time step: 720
# Episode: 180, Time step: 750
# Episode: 180, Time step: 780
# Episode: 181, Time step: 0
# Episode: 181, Time step: 30
# Episode: 181, Time step: 60
# Episode: 181, Time step: 90
# Episode: 181, Time step: 120
# Episode: 181, Time step: 150
# Episode: 181, Time step: 180
# Episode: 181, Time step: 210
# Episode: 181, Time step: 240
# Episode: 181, Time step: 270
# Episode: 181, Time step: 300
# Episode: 181, Time step: 330
# Episode: 181, Time step: 360
# Episode: 181, Time step: 390
# Episode: 181, Time step: 420
# Episode: 181, Time step: 450
# Episode: 181, Time step: 480
# Episode: 181, Time step: 510
# Episode: 181, Time step: 540
# Episode: 181, Time step: 570
# Episode: 181, Time step: 600
# Episode: 181, Time step: 630
# Episode: 181, Time step: 660
# Episode: 181, Time step: 690
# Episode: 181, Time step: 720
# Episode: 181, Time step: 750
# Episode: 181, Time step: 780
# Episode: 182, Time step: 0
# Episode: 182, Time step: 30
# Episode: 182, Time step: 60
# Episode: 182, Time step: 90
# Episode: 182, Time step: 120
# Episode: 182, Time step: 150
# Episode: 182, Time step: 180
# Episode: 182, Time step: 210
# Episode: 182, Time step: 240
# Episode: 182, Time step: 270
# Episode: 182, Time step: 300
# Episode: 182, Time step: 330
# Episode: 182, Time step: 360
# Episode: 182, Time step: 390
# Episode: 182, Time step: 420
# Episode: 182, Time step: 450
# Episode: 182, Time step: 480
# Episode: 182, Time step: 510
# Episode: 182, Time step: 540
# Episode: 182, Time step: 570
# Episode: 182, Time step: 600
# Episode: 182, Time step: 630
# Episode: 182, Time step: 660
# Episode: 182, Time step: 690
# Episode: 182, Time step: 720
# Episode: 182, Time step: 750
# Episode: 182, Time step: 780
# Episode: 183, Time step: 0
# Episode: 183, Time step: 30
# Episode: 183, Time step: 60
# Episode: 183, Time step: 90
# Episode: 183, Time step: 120
# Episode: 183, Time step: 150
# Episode: 183, Time step: 180
# Episode: 183, Time step: 210
# Episode: 183, Time step: 240
# Episode: 183, Time step: 270
# Episode: 183, Time step: 300
# Episode: 183, Time step: 330
# Episode: 183, Time step: 360
# Episode: 183, Time step: 390
# Episode: 183, Time step: 420
# Episode: 183, Time step: 450
# Episode: 183, Time step: 480
# Episode: 183, Time step: 510
# Episode: 183, Time step: 540
# Episode: 183, Time step: 570
# Episode: 183, Time step: 600
# Episode: 183, Time step: 630
# Episode: 183, Time step: 660
# Episode: 183, Time step: 690
# Episode: 183, Time step: 720
# Episode: 183, Time step: 750
# Episode: 183, Time step: 780
# Episode: 184, Time step: 0
# Episode: 184, Time step: 30
# Episode: 184, Time step: 60
# Episode: 184, Time step: 90
# Episode: 184, Time step: 120
# Episode: 184, Time step: 150
# Episode: 184, Time step: 180
# Episode: 184, Time step: 210
# Episode: 184, Time step: 240
# Episode: 184, Time step: 270
# Episode: 184, Time step: 300
# Episode: 184, Time step: 330
# Episode: 184, Time step: 360
# Episode: 184, Time step: 390
# Episode: 184, Time step: 420
# Episode: 184, Time step: 450
# Episode: 184, Time step: 480
# Episode: 184, Time step: 510
# Episode: 184, Time step: 540
# Episode: 184, Time step: 570
# Episode: 184, Time step: 600
# Episode: 184, Time step: 630
# Episode: 184, Time step: 660
# Episode: 184, Time step: 690
# Episode: 184, Time step: 720
# Episode: 184, Time step: 750
# Episode: 184, Time step: 780
# Episode: 185, Time step: 0
# Episode: 185, Time step: 30
# Episode: 185, Time step: 60
# Episode: 185, Time step: 90
# Episode: 185, Time step: 120
# Episode: 185, Time step: 150
# Episode: 185, Time step: 180
# Episode: 185, Time step: 210
# Episode: 185, Time step: 240
# Episode: 185, Time step: 270
# Episode: 185, Time step: 300
# Episode: 185, Time step: 330
# Episode: 185, Time step: 360
# Episode: 185, Time step: 390
# Episode: 185, Time step: 420
# Episode: 185, Time step: 450
# Episode: 185, Time step: 480
# Episode: 185, Time step: 510
# Episode: 185, Time step: 540
# Episode: 185, Time step: 570
# Episode: 185, Time step: 600
# Episode: 185, Time step: 630
# Episode: 185, Time step: 660
# Episode: 185, Time step: 690
# Episode: 185, Time step: 720
# Episode: 185, Time step: 750
# Episode: 185, Time step: 780
# Episode: 186, Time step: 0
# Episode: 186, Time step: 30
# Episode: 186, Time step: 60
# Episode: 186, Time step: 90
# Episode: 186, Time step: 120
# Episode: 186, Time step: 150
# Episode: 186, Time step: 180
# Episode: 186, Time step: 210
# Episode: 186, Time step: 240
# Episode: 186, Time step: 270
# Episode: 186, Time step: 300
# Episode: 186, Time step: 330
# Episode: 186, Time step: 360
# Episode: 186, Time step: 390
# Episode: 186, Time step: 420
# Episode: 186, Time step: 450
# Episode: 186, Time step: 480
# Episode: 186, Time step: 510
# Episode: 186, Time step: 540
# Episode: 186, Time step: 570
# Episode: 186, Time step: 600
# Episode: 186, Time step: 630
# Episode: 186, Time step: 660
# Episode: 186, Time step: 690
# Episode: 186, Time step: 720
# Episode: 186, Time step: 750
# Episode: 186, Time step: 780
# Episode: 187, Time step: 0
# Episode: 187, Time step: 30
# Episode: 187, Time step: 60
# Episode: 187, Time step: 90
# Episode: 187, Time step: 120
# Episode: 187, Time step: 150
# Episode: 187, Time step: 180
# Episode: 187, Time step: 210
# Episode: 187, Time step: 240
# Episode: 187, Time step: 270
# Episode: 187, Time step: 300
# Episode: 187, Time step: 330
# Episode: 187, Time step: 360
# Episode: 187, Time step: 390
# Episode: 187, Time step: 420
# Episode: 187, Time step: 450
# Episode: 187, Time step: 480
# Episode: 187, Time step: 510
# Episode: 187, Time step: 540
# Episode: 187, Time step: 570
# Episode: 187, Time step: 600
# Episode: 187, Time step: 630
# Episode: 187, Time step: 660
# Episode: 187, Time step: 690
# Episode: 187, Time step: 720
# Episode: 187, Time step: 750
# Episode: 187, Time step: 780
# Episode: 188, Time step: 0
# Episode: 188, Time step: 30
# Episode: 188, Time step: 60
# Episode: 188, Time step: 90
# Episode: 188, Time step: 120
# Episode: 188, Time step: 150
# Episode: 188, Time step: 180
# Episode: 188, Time step: 210
# Episode: 188, Time step: 240
# Episode: 188, Time step: 270
# Episode: 188, Time step: 300
# Episode: 188, Time step: 330
# Episode: 188, Time step: 360
# Episode: 188, Time step: 390
# Episode: 188, Time step: 420
# Episode: 188, Time step: 450
# Episode: 188, Time step: 480
# Episode: 188, Time step: 510
# Episode: 188, Time step: 540
# Episode: 188, Time step: 570
# Episode: 188, Time step: 600
# Episode: 188, Time step: 630
# Episode: 188, Time step: 660
# Episode: 188, Time step: 690
# Episode: 188, Time step: 720
# Episode: 188, Time step: 750
# Episode: 188, Time step: 780
# Episode: 189, Time step: 0
# Episode: 189, Time step: 30
# Episode: 189, Time step: 60
# Episode: 189, Time step: 90
# Episode: 189, Time step: 120
# Episode: 189, Time step: 150
# Episode: 189, Time step: 180
# Episode: 189, Time step: 210
# Episode: 189, Time step: 240
# Episode: 189, Time step: 270
# Episode: 189, Time step: 300
# Episode: 189, Time step: 330
# Episode: 189, Time step: 360
# Episode: 189, Time step: 390
# Episode: 189, Time step: 420
# Episode: 189, Time step: 450
# Episode: 189, Time step: 480
# Episode: 189, Time step: 510
# Episode: 189, Time step: 540
# Episode: 189, Time step: 570
# Episode: 189, Time step: 600
# Episode: 189, Time step: 630
# Episode: 189, Time step: 660
# Episode: 189, Time step: 690
# Episode: 189, Time step: 720
# Episode: 189, Time step: 750
# Episode: 189, Time step: 780
# Episode: 190, Time step: 0
# Episode: 190, Time step: 30
# Episode: 190, Time step: 60
# Episode: 190, Time step: 90
# Episode: 190, Time step: 120
# Episode: 190, Time step: 150
# Episode: 190, Time step: 180
# Episode: 190, Time step: 210
# Episode: 190, Time step: 240
# Episode: 190, Time step: 270
# Episode: 190, Time step: 300
# Episode: 190, Time step: 330
# Episode: 190, Time step: 360
# Episode: 190, Time step: 390
# Episode: 190, Time step: 420
# Episode: 190, Time step: 450
# Episode: 190, Time step: 480
# Episode: 190, Time step: 510
# Episode: 190, Time step: 540
# Episode: 190, Time step: 570
# Episode: 190, Time step: 600
# Episode: 190, Time step: 630
# Episode: 190, Time step: 660
# Episode: 190, Time step: 690
# Episode: 190, Time step: 720
# Episode: 190, Time step: 750
# Episode: 190, Time step: 780
# Episode: 191, Time step: 0
# Episode: 191, Time step: 30
# Episode: 191, Time step: 60
# Episode: 191, Time step: 90
# Episode: 191, Time step: 120
# Episode: 191, Time step: 150
# Episode: 191, Time step: 180
# Episode: 191, Time step: 210
# Episode: 191, Time step: 240
# Episode: 191, Time step: 270
# Episode: 191, Time step: 300
# Episode: 191, Time step: 330
# Episode: 191, Time step: 360
# Episode: 191, Time step: 390
# Episode: 191, Time step: 420
# Episode: 191, Time step: 450
# Episode: 191, Time step: 480
# Episode: 191, Time step: 510
# Episode: 191, Time step: 540
# Episode: 191, Time step: 570
# Episode: 191, Time step: 600
# Episode: 191, Time step: 630
# Episode: 191, Time step: 660
# Episode: 191, Time step: 690
# Episode: 191, Time step: 720
# Episode: 191, Time step: 750
# Episode: 191, Time step: 780
# Episode: 192, Time step: 0
# Episode: 192, Time step: 30
# Episode: 192, Time step: 60
# Episode: 192, Time step: 90
# Episode: 192, Time step: 120
# Episode: 192, Time step: 150
# Episode: 192, Time step: 180
# Episode: 192, Time step: 210
# Episode: 192, Time step: 240
# Episode: 192, Time step: 270
# Episode: 192, Time step: 300
# Episode: 192, Time step: 330
# Episode: 192, Time step: 360
# Episode: 192, Time step: 390
# Episode: 192, Time step: 420
# Episode: 192, Time step: 450
# Episode: 192, Time step: 480
# Episode: 192, Time step: 510
# Episode: 192, Time step: 540
# Episode: 192, Time step: 570
# Episode: 192, Time step: 600
# Episode: 192, Time step: 630
# Episode: 192, Time step: 660
# Episode: 192, Time step: 690
# Episode: 192, Time step: 720
# Episode: 192, Time step: 750
# Episode: 192, Time step: 780
# Episode: 193, Time step: 0
# Episode: 193, Time step: 30
# Episode: 193, Time step: 60
# Episode: 193, Time step: 90
# Episode: 193, Time step: 120
# Episode: 193, Time step: 150
# Episode: 193, Time step: 180
# Episode: 193, Time step: 210
# Episode: 193, Time step: 240
# Episode: 193, Time step: 270
# Episode: 193, Time step: 300
# Episode: 193, Time step: 330
# Episode: 193, Time step: 360
# Episode: 193, Time step: 390
# Episode: 193, Time step: 420
# Episode: 193, Time step: 450
# Episode: 193, Time step: 480
# Episode: 193, Time step: 510
# Episode: 193, Time step: 540
# Episode: 193, Time step: 570
# Episode: 193, Time step: 600
# Episode: 193, Time step: 630
# Episode: 193, Time step: 660
# Episode: 193, Time step: 690
# Episode: 193, Time step: 720
# Episode: 193, Time step: 750
# Episode: 193, Time step: 780
# Episode: 194, Time step: 0
# Episode: 194, Time step: 30
# Episode: 194, Time step: 60
# Episode: 194, Time step: 90
# Episode: 194, Time step: 120
# Episode: 194, Time step: 150
# Episode: 194, Time step: 180
# Episode: 194, Time step: 210
# Episode: 194, Time step: 240
# Episode: 194, Time step: 270
# Episode: 194, Time step: 300
# Episode: 194, Time step: 330
# Episode: 194, Time step: 360
# Episode: 194, Time step: 390
# Episode: 194, Time step: 420
# Episode: 194, Time step: 450
# Episode: 194, Time step: 480
# Episode: 194, Time step: 510
# Episode: 194, Time step: 540
# Episode: 194, Time step: 570
# Episode: 194, Time step: 600
# Episode: 194, Time step: 630
# Episode: 194, Time step: 660
# Episode: 194, Time step: 690
# Episode: 194, Time step: 720
# Episode: 194, Time step: 750
# Episode: 194, Time step: 780
# Episode: 195, Time step: 0
# Episode: 195, Time step: 30
# Episode: 195, Time step: 60
# Episode: 195, Time step: 90
# Episode: 195, Time step: 120
# Episode: 195, Time step: 150
# Episode: 195, Time step: 180
# Episode: 195, Time step: 210
# Episode: 195, Time step: 240
# Episode: 195, Time step: 270
# Episode: 195, Time step: 300
# Episode: 195, Time step: 330
# Episode: 195, Time step: 360
# Episode: 195, Time step: 390
# Episode: 195, Time step: 420
# Episode: 195, Time step: 450
# Episode: 195, Time step: 480
# Episode: 195, Time step: 510
# Episode: 195, Time step: 540
# Episode: 195, Time step: 570
# Episode: 195, Time step: 600
# Episode: 195, Time step: 630
# Episode: 195, Time step: 660
# Episode: 195, Time step: 690
# Episode: 195, Time step: 720
# Episode: 195, Time step: 750
# Episode: 195, Time step: 780
# Episode: 196, Time step: 0
# Episode: 196, Time step: 30
# Episode: 196, Time step: 60
# Episode: 196, Time step: 90
# Episode: 196, Time step: 120
# Episode: 196, Time step: 150
# Episode: 196, Time step: 180
# Episode: 196, Time step: 210
# Episode: 196, Time step: 240
# Episode: 196, Time step: 270
# Episode: 196, Time step: 300
# Episode: 196, Time step: 330
# Episode: 196, Time step: 360
# Episode: 196, Time step: 390
# Episode: 196, Time step: 420
# Episode: 196, Time step: 450
# Episode: 196, Time step: 480
# Episode: 196, Time step: 510
# Episode: 196, Time step: 540
# Episode: 196, Time step: 570
# Episode: 196, Time step: 600
# Episode: 196, Time step: 630
# Episode: 196, Time step: 660
# Episode: 196, Time step: 690
# Episode: 196, Time step: 720
# Episode: 196, Time step: 750
# Episode: 196, Time step: 780
# Episode: 197, Time step: 0
# Episode: 197, Time step: 30
# Episode: 197, Time step: 60
# Episode: 197, Time step: 90
# Episode: 197, Time step: 120
# Episode: 197, Time step: 150
# Episode: 197, Time step: 180
# Episode: 197, Time step: 210
# Episode: 197, Time step: 240
# Episode: 197, Time step: 270
# Episode: 197, Time step: 300
# Episode: 197, Time step: 330
# Episode: 197, Time step: 360
# Episode: 197, Time step: 390
# Episode: 197, Time step: 420
# Episode: 197, Time step: 450
# Episode: 197, Time step: 480
# Episode: 197, Time step: 510
# Episode: 197, Time step: 540
# Episode: 197, Time step: 570
# Episode: 197, Time step: 600
# Episode: 197, Time step: 630
# Episode: 197, Time step: 660
# Episode: 197, Time step: 690
# Episode: 197, Time step: 720
# Episode: 197, Time step: 750
# Episode: 197, Time step: 780
# Episode: 198, Time step: 0
# Episode: 198, Time step: 30
# Episode: 198, Time step: 60
# Episode: 198, Time step: 90
# Episode: 198, Time step: 120
# Episode: 198, Time step: 150
# Episode: 198, Time step: 180
# Episode: 198, Time step: 210
# Episode: 198, Time step: 240
# Episode: 198, Time step: 270
# Episode: 198, Time step: 300
# Episode: 198, Time step: 330
# Episode: 198, Time step: 360
# Episode: 198, Time step: 390
# Episode: 198, Time step: 420
# Episode: 198, Time step: 450
# Episode: 198, Time step: 480
# Episode: 198, Time step: 510
# Episode: 198, Time step: 540
# Episode: 198, Time step: 570
# Episode: 198, Time step: 600
# Episode: 198, Time step: 630
# Episode: 198, Time step: 660
# Episode: 198, Time step: 690
# Episode: 198, Time step: 720
# Episode: 198, Time step: 750
# Episode: 198, Time step: 780
# Episode: 199, Time step: 0
# Episode: 199, Time step: 30
# Episode: 199, Time step: 60

# %%
# Load the results
x_coordinate_values = np.load('x_coordinate_values.npy')
y_coordinate_values = np.load('y_coordinate_values.npy')
th_values = np.load('th_values.npy')
th_dot_values = np.load('th_dot_values.npy')
action_values = np.load('action_values.npy')
reward_values = np.load('reward_values.npy')
weight_values = np.load('weight_values.npy')
td_error_values = np.load('td_error_values.npy')
epsilon_values = np.load('epsilon_values.npy')
num_episode = np.load('num_episode.npy')
num_time_steps = np.load('num_time_steps.npy')

# %%
plt.figure(figsize=(15, 10))
i = np.argmax(np.mean(reward_values, axis=1)) # np.argmin(np.mean(reward_values, axis=1)) or -1 or any other value

plt.subplot(4,2,1)
plt.plot(th_values[i, :])
plt.xlabel('Time Step')
plt.ylabel('Theta (deg)')

plt.subplot(4,2,2)
plt.plot(th_dot_values[i, :])
plt.xlabel('Time Step')
plt.ylabel('Angular Velocity (rad/s)')

plt.subplot(4,2,3)
plt.plot(x_coordinate_values[i, :])
plt.xlabel('Time Step')
plt.ylabel('X Coordinate (m)')

plt.subplot(4,2,4)
plt.plot(y_coordinate_values[i, :])
plt.xlabel('Time Step')
plt.ylabel('Y Coordinate (m)')

plt.subplot(4,2,5)
plt.plot(action_values[i, :])
plt.xlabel('Time Step')
plt.ylabel('Applied Torque (N.m)')

plt.subplot(4,2,6)
eps = np.array([0.50*0.995**i for i in range(800)])
plt.plot(eps);
plt.xlabel('Time Step')
plt.ylabel('Epsilon')

plt.tight_layout()
plt.show()

# %%
averaged_rewards = np.mean(reward_values, axis=1)
plt.plot(averaged_rewards[0: -1: 1]);
plt.xlabel('Episode')
plt.ylabel('Averaged Reward');

# %%
plt.plot(reward_values[i, :])
plt.xlabel('Time Steps')
plt.ylabel('Averaged Reward')
plt.show()

# %%
plt.figure(figsize=(15, 10))
e = -1
t = -1

plt.subplot(3,2,1)
plt.plot(weight_values[e, :, 0])
plt.xlabel('Time Step')
plt.ylabel('w1')

plt.subplot(3,2,2)
plt.plot(weight_values[e, :, 1])
plt.xlabel('Time Step')
plt.ylabel('w2')

plt.subplot(3,2,3)
plt.plot(weight_values[e, :, 2])
plt.xlabel('Time Step')
plt.ylabel('w3')

plt.subplot(3,2,4)
plt.plot(weight_values[e, :, 3])
plt.xlabel('Time Step')
plt.ylabel('w4')

plt.subplot(3,2,5)
plt.plot(weight_values[e, :, 4])
plt.xlabel('Time Step')
plt.ylabel('w5')

plt.subplot(3,2,6)
plt.plot(weight_values[e, :, 5])
plt.xlabel('Time Step')
plt.ylabel('w6')

plt.tight_layout()

# %%
e = -1

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.scatter(th_values[e, :], th_dot_values[e, :])
plt.xlabel('theta')
plt.ylabel('theta dot');

plt.subplot(1, 2, 2)
plt.scatter(th_values[e, :], action_values[e, :])
plt.xlabel('theta')
plt.ylabel('action');
