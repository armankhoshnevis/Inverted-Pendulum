# %%
import numpy as np
import gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Initialize the environment
env = gym.make("Pendulum-v1", render_mode="rgb_array")

# Number of features at each state
num_states = env.observation_space.shape[0]

# Lower and upper bound of the action space
upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

# Discretize the continuous action space
num_actions = 41
discritized_actions = np.linspace(env.action_space.low[0], env.action_space.high[0], num_actions)

# %%
# Transition as a namedtuple: a simple data structure to group together s_t, a_t, r, s_t+1
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state'))

# Cyclic buffer: holds the recent transitions + sampling a random batch of transitions for training
class ReplayBuffer(object):

    def __init__(self, capacity=10_000):
        # deque is used to automatically discard the oldest data
        self.memory = deque([], maxlen=capacity)

    # Save a new transition in the replay buffer
    def push(self, *args):
        self.memory.append(Transition(*args))
        
    # Randomly sample a batch of transitions from the replay buffer to train the agent
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    # Current size of the replay buffer
    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):
    
    # Initialize the network with three fully connected layers
    def __init__(self, num_states, num_actions):
        # DQN class inherits from the nn.Module, which is the base class for all nn modules 
        super(DQN, self).__init__()
        self.hl1 = nn.Linear(num_states, 128)
        self.hl2 = nn.Linear(128, 128)
        self.output_layer = nn.Linear(128, num_actions)
    
    # Forward pass of the nn
    def forward(self, x):
        x = F.relu(self.hl1(x))
        x = F.relu(self.hl2(x))
        return self.output_layer(x)

# %%
# Number of transitions sampled from the replay buffer
BATCH_SIZE = 128

# Discount factor
GAMMA = 0.99

# Starting and final value of epsilon + its decay rate
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 150
# plt.plot([EPS_END + (EPS_START - EPS_END) * math.exp(-1. * s_d / 150) for s_d in range(800)]);

# Update rate of the target network
TAU = 0.005

# Number of state observations
state, info = env.reset()
num_states = len(state)

# Initialize the networks
q_network = DQN(num_states, num_actions).to(device)
target_q_network = DQN(num_states, num_actions).to(device)
target_q_network.load_state_dict(q_network.state_dict())

'''
# In case you want to load the model parameters of the networks
# Load the learned network model parameters
loaded_q_network_params_dict = torch.load('q_network_params_dict.pth')
loaded_target_q_network_params_dict = torch.load('target_q_network_params_dict.pth')
q_network.load_state_dict(loaded_q_network_params_dict)
target_q_network.load_state_dict(loaded_target_q_network_params_dict)
'''

# Learning rate of the AdamW optimizer
LR = 1e-4

# Initialize the optimizer
optimizer = optim.AdamW(q_network.parameters(), lr=LR, amsgrad=True)

# Initialize the buffer memory
BUFFER_CAPACITY = 10_000
buffer_memory = ReplayBuffer(capacity=BUFFER_CAPACITY)

# Select action using epsilon-greedy policy
def select_action(state, time_step):  # state is assumed to be a tensor with a size of [1, num_state]
    eps_sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * time_step / EPS_DECAY)
    
    # Exploitation
    if eps_sample > eps_threshold:
        with torch.no_grad():  # To enable using .max method later + reduce memory consumption
            action_q_values = q_network(state)
            max_action_q_index = action_q_values.max(1)[1].item()
            action = discritized_actions[max_action_q_index]
            
            # Pendulum-v1 receives an action as a numpy array
            return np.array([action])
    
    # Exploration
    else:
        random_action_index = random.randrange(len(discritized_actions))
        random_action = discritized_actions[random_action_index]
        
        # Pendulum-v1 receives an action as a numpy array
        return np.array([random_action])

# %%
# Determine the index of actions that are sampled from the buffer memory
def action_to_index(action_batch, discritized_actions):
    action_to_index_dict = {round(action_value, 1): index for index, action_value in enumerate(discritized_actions)}
    action_indices = torch.tensor([action_to_index_dict[round(action.item(), 2)] for action in action_batch], device=device, dtype=torch.int64)
    return action_indices

# Learning!
def optimize_model():
    # Check if the buffer memory has enough transitions to sample a batch
    if len(buffer_memory)<BATCH_SIZE:
        return
    
    # Sample a batch of transitions from the buffer memory
    transitions = buffer_memory.sample(BATCH_SIZE)
    
    # Transpose the sampled batch to separate its components (state, action, reward, next_state) 
    batch = Transition(*zip(*transitions))
    
    # Concatenate state, action, reward, and next_state batches into separate tensors
    state_batch = torch.cat(batch.state)  # size: [BATCH_SIZE, num_states]
    action_batch = torch.cat(batch.action)  # size: [BATCH_SIZE]
    reward_batch = torch.cat(batch.reward)  # size: [BATCH_SIZE]
    next_state_batch = torch.cat(batch.next_state)  # size: [BATCH_SIZE, num_states]
    
    # state_batch.to(device)
    # action_batch.to(device)
    # reward_batch.to(device)
    # next_state_batch.to(device)
    
    # Q-values for each possible action
    q_values = q_network(state_batch)  # size: [BATCH_SIZE, num_actions]
    
    # Determine which actions were sampled
    sampled_action_indices = action_to_index(action_batch, discritized_actions)
    
    # Q(s_t, a_t): Q-values corresponds to sampled (s_t, a_t) batch
    q_values_current = q_values.gather(1, sampled_action_indices.unsqueeze(1))  # size: [BATCH_SIZE, 1]
    
    # Q-values of the next state for each possible action
    with torch.no_grad():  # Gradients are not required for updating the weights of the target Q-network
        q_values_next_state = target_q_network(next_state_batch)  # size: [BATCH_SIZE, num_actions]
    
    # Q-Target: r + gamma * max(Q(s_t, a'))
    q_values_target = (reward_batch + GAMMA * q_values_next_state.max(1).values).unsqueeze(1)  # size: [BATCH_SIZE, 1]
    
    # Compute Hubber loss
    huber_loss = nn.SmoothL1Loss()
    loss = huber_loss(q_values_current, q_values_target)
    
    # Optimize the neural network model
    # Clear old gradients to compute new gradients for each optimization step
    optimizer.zero_grad()  
    
    # Compute the gradients of the loss by backpropagation
    loss.backward()
    
    # In-place gradient clipping: a technique to prevent exploding gradients
    torch.nn.utils.clip_grad_value_(q_network.parameters(), 100)
    
    # Update the weights of the q-network
    optimizer.step()

# %%
# Main training loop

# Loop parameters
num_episodes = 600
env._max_episode_steps = 200
num_time_steps = env._max_episode_steps

# Pre-allocation
reward_per_time_step = np.zeros([num_episodes, num_time_steps])
average_reward_per_episode = np.zeros([num_episodes])
x_coordinate_per_time_step = np.zeros([num_episodes, num_time_steps])
y_coordinate_per_time_step = np.zeros([num_episodes, num_time_steps])
angular_velocity_per_time_step = np.zeros([num_episodes, num_time_steps])
action_per_time_step = np.zeros([num_episodes, num_time_steps])

for episode in range(num_episodes):
    # Initialize the environment
    state, info = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)  # size: [1, num_state]
    
    for time_step in range(num_time_steps):
        # Store the state values
        x_coordinate_per_time_step[episode, time_step] = state[0][0].numpy()
        y_coordinate_per_time_step[episode, time_step] = state[0][1].numpy()
        angular_velocity_per_time_step[episode, time_step] = state[0][2].numpy()
        
        # Epsilon-greedy policy
        action_nparray = select_action(state, time_step)
        
        # Store the selected action
        action_per_time_step[episode, time_step] = action_nparray[0]
        
        # Take the selected action
        observation, reward, _, _, _ = env.step(action_nparray)
        
        # Convert to tensors with proper shapes
        action_tensor = torch.tensor(action_nparray, dtype=torch.float32, device=device)
        reward = torch.tensor([reward], dtype=torch.float32, device=device)
        next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
        
        # Store the transition in memory
        buffer_memory.push(state, action_tensor, reward, next_state)
        
        # Optimize the Q-network
        optimize_model()
        
        # Update the traget Q-network: θ′ ← τ θ + (1 − τ)θ′
        target_q_network_params = target_q_network.state_dict()  # θ′
        q_network_parmas = q_network.state_dict()  # θ
        for key in q_network_parmas:
            target_q_network_params[key] = TAU*q_network_parmas[key] + (1-TAU)*target_q_network_params[key]  # τ θ + (1 − τ)θ′
        target_q_network.load_state_dict(target_q_network_params)  # Updated θ′
        
        # Store the reward
        reward_per_time_step[episode, time_step] = reward
        
        # Move to the next state
        state = next_state
        
        # Progress in episodes and time steps
        if time_step%25 == 0:
           print(f'Episode: {episode}, Time step: {time_step}')
    
    # Store the averaged reward
    average_reward_per_episode[episode] = np.mean(reward_per_time_step[episode, :])

np.save('reward_per_time_step.npy', reward_per_time_step)
np.save('average_reward_per_episode.npy', average_reward_per_episode)
np.save('x_coordinate_per_time_step.npy', x_coordinate_per_time_step)
np.save('y_coordinate_per_time_step.npy', y_coordinate_per_time_step)
np.save('angular_velocity_per_time_step.npy', angular_velocity_per_time_step)
np.save('action_per_time_step.npy', action_per_time_step)
np.save('num_time_steps.npy', num_time_steps)
np.save('num_episodes.npy', num_episodes)
# Out:
# /mnt/home/khoshne1/anaconda3/envs/my_env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode: 0, Time step: 0
# Episode: 0, Time step: 25
# Episode: 0, Time step: 50
# Episode: 0, Time step: 75
# Episode: 0, Time step: 100
# Episode: 0, Time step: 125
# Episode: 0, Time step: 150
# Episode: 0, Time step: 175
# Episode: 1, Time step: 0
# Episode: 1, Time step: 25
# Episode: 1, Time step: 50
# Episode: 1, Time step: 75
# Episode: 1, Time step: 100
# Episode: 1, Time step: 125
# Episode: 1, Time step: 150
# Episode: 1, Time step: 175
# Episode: 2, Time step: 0
# Episode: 2, Time step: 25
# Episode: 2, Time step: 50
# Episode: 2, Time step: 75
# Episode: 2, Time step: 100
# Episode: 2, Time step: 125
# Episode: 2, Time step: 150
# Episode: 2, Time step: 175
# Episode: 3, Time step: 0
# Episode: 3, Time step: 25
# Episode: 3, Time step: 50
# Episode: 3, Time step: 75
# Episode: 3, Time step: 100
# Episode: 3, Time step: 125
# Episode: 3, Time step: 150
# Episode: 3, Time step: 175
# Episode: 4, Time step: 0
# Episode: 4, Time step: 25
# Episode: 4, Time step: 50
# Episode: 4, Time step: 75
# Episode: 4, Time step: 100
# Episode: 4, Time step: 125
# Episode: 4, Time step: 150
# Episode: 4, Time step: 175
# Episode: 5, Time step: 0
# Episode: 5, Time step: 25
# Episode: 5, Time step: 50
# Episode: 5, Time step: 75
# Episode: 5, Time step: 100
# Episode: 5, Time step: 125
# Episode: 5, Time step: 150
# Episode: 5, Time step: 175
# Episode: 6, Time step: 0
# Episode: 6, Time step: 25
# Episode: 6, Time step: 50
# Episode: 6, Time step: 75
# Episode: 6, Time step: 100
# Episode: 6, Time step: 125
# Episode: 6, Time step: 150
# Episode: 6, Time step: 175
# Episode: 7, Time step: 0
# Episode: 7, Time step: 25
# Episode: 7, Time step: 50
# Episode: 7, Time step: 75
# Episode: 7, Time step: 100
# Episode: 7, Time step: 125
# Episode: 7, Time step: 150
# Episode: 7, Time step: 175
# Episode: 8, Time step: 0
# Episode: 8, Time step: 25
# Episode: 8, Time step: 50
# Episode: 8, Time step: 75
# Episode: 8, Time step: 100
# Episode: 8, Time step: 125
# Episode: 8, Time step: 150
# Episode: 8, Time step: 175
# Episode: 9, Time step: 0
# Episode: 9, Time step: 25
# Episode: 9, Time step: 50
# Episode: 9, Time step: 75
# Episode: 9, Time step: 100
# Episode: 9, Time step: 125
# Episode: 9, Time step: 150
# Episode: 9, Time step: 175
# Episode: 10, Time step: 0
# Episode: 10, Time step: 25
# Episode: 10, Time step: 50
# Episode: 10, Time step: 75
# Episode: 10, Time step: 100
# Episode: 10, Time step: 125
# Episode: 10, Time step: 150
# Episode: 10, Time step: 175
# Episode: 11, Time step: 0
# Episode: 11, Time step: 25
# Episode: 11, Time step: 50
# Episode: 11, Time step: 75
# Episode: 11, Time step: 100
# Episode: 11, Time step: 125
# Episode: 11, Time step: 150
# Episode: 11, Time step: 175
# Episode: 12, Time step: 0
# Episode: 12, Time step: 25
# Episode: 12, Time step: 50
# Episode: 12, Time step: 75
# Episode: 12, Time step: 100
# Episode: 12, Time step: 125
# Episode: 12, Time step: 150
# Episode: 12, Time step: 175
# Episode: 13, Time step: 0
# Episode: 13, Time step: 25
# Episode: 13, Time step: 50
# Episode: 13, Time step: 75
# Episode: 13, Time step: 100
# Episode: 13, Time step: 125
# Episode: 13, Time step: 150
# Episode: 13, Time step: 175
# Episode: 14, Time step: 0
# Episode: 14, Time step: 25
# Episode: 14, Time step: 50
# Episode: 14, Time step: 75
# Episode: 14, Time step: 100
# Episode: 14, Time step: 125
# Episode: 14, Time step: 150
# Episode: 14, Time step: 175
# Episode: 15, Time step: 0
# Episode: 15, Time step: 25
# Episode: 15, Time step: 50
# Episode: 15, Time step: 75
# Episode: 15, Time step: 100
# Episode: 15, Time step: 125
# Episode: 15, Time step: 150
# Episode: 15, Time step: 175
# Episode: 16, Time step: 0
# Episode: 16, Time step: 25
# Episode: 16, Time step: 50
# Episode: 16, Time step: 75
# Episode: 16, Time step: 100
# Episode: 16, Time step: 125
# Episode: 16, Time step: 150
# Episode: 16, Time step: 175
# Episode: 17, Time step: 0
# Episode: 17, Time step: 25
# Episode: 17, Time step: 50
# Episode: 17, Time step: 75
# Episode: 17, Time step: 100
# Episode: 17, Time step: 125
# Episode: 17, Time step: 150
# Episode: 17, Time step: 175
# Episode: 18, Time step: 0
# Episode: 18, Time step: 25
# Episode: 18, Time step: 50
# Episode: 18, Time step: 75
# Episode: 18, Time step: 100
# Episode: 18, Time step: 125
# Episode: 18, Time step: 150
# Episode: 18, Time step: 175
# Episode: 19, Time step: 0
# Episode: 19, Time step: 25
# Episode: 19, Time step: 50
# Episode: 19, Time step: 75
# Episode: 19, Time step: 100
# Episode: 19, Time step: 125
# Episode: 19, Time step: 150
# Episode: 19, Time step: 175
# Episode: 20, Time step: 0
# Episode: 20, Time step: 25
# Episode: 20, Time step: 50
# Episode: 20, Time step: 75
# Episode: 20, Time step: 100
# Episode: 20, Time step: 125
# Episode: 20, Time step: 150
# Episode: 20, Time step: 175
# Episode: 21, Time step: 0
# Episode: 21, Time step: 25
# Episode: 21, Time step: 50
# Episode: 21, Time step: 75
# Episode: 21, Time step: 100
# Episode: 21, Time step: 125
# Episode: 21, Time step: 150
# Episode: 21, Time step: 175
# Episode: 22, Time step: 0
# Episode: 22, Time step: 25
# Episode: 22, Time step: 50
# Episode: 22, Time step: 75
# Episode: 22, Time step: 100
# Episode: 22, Time step: 125
# Episode: 22, Time step: 150
# Episode: 22, Time step: 175
# Episode: 23, Time step: 0
# Episode: 23, Time step: 25
# Episode: 23, Time step: 50
# Episode: 23, Time step: 75
# Episode: 23, Time step: 100
# Episode: 23, Time step: 125
# Episode: 23, Time step: 150
# Episode: 23, Time step: 175
# Episode: 24, Time step: 0
# Episode: 24, Time step: 25
# Episode: 24, Time step: 50
# Episode: 24, Time step: 75
# Episode: 24, Time step: 100
# Episode: 24, Time step: 125
# Episode: 24, Time step: 150
# Episode: 24, Time step: 175
# Episode: 25, Time step: 0
# Episode: 25, Time step: 25
# Episode: 25, Time step: 50
# Episode: 25, Time step: 75
# Episode: 25, Time step: 100
# Episode: 25, Time step: 125
# Episode: 25, Time step: 150
# Episode: 25, Time step: 175
# Episode: 26, Time step: 0
# Episode: 26, Time step: 25
# Episode: 26, Time step: 50
# Episode: 26, Time step: 75
# Episode: 26, Time step: 100
# Episode: 26, Time step: 125
# Episode: 26, Time step: 150
# Episode: 26, Time step: 175
# Episode: 27, Time step: 0
# Episode: 27, Time step: 25
# Episode: 27, Time step: 50
# Episode: 27, Time step: 75
# Episode: 27, Time step: 100
# Episode: 27, Time step: 125
# Episode: 27, Time step: 150
# Episode: 27, Time step: 175
# Episode: 28, Time step: 0
# Episode: 28, Time step: 25
# Episode: 28, Time step: 50
# Episode: 28, Time step: 75
# Episode: 28, Time step: 100
# Episode: 28, Time step: 125
# Episode: 28, Time step: 150
# Episode: 28, Time step: 175
# Episode: 29, Time step: 0
# Episode: 29, Time step: 25
# Episode: 29, Time step: 50
# Episode: 29, Time step: 75
# Episode: 29, Time step: 100
# Episode: 29, Time step: 125
# Episode: 29, Time step: 150
# Episode: 29, Time step: 175
# Episode: 30, Time step: 0
# Episode: 30, Time step: 25
# Episode: 30, Time step: 50
# Episode: 30, Time step: 75
# Episode: 30, Time step: 100
# Episode: 30, Time step: 125
# Episode: 30, Time step: 150
# Episode: 30, Time step: 175
# Episode: 31, Time step: 0
# Episode: 31, Time step: 25
# Episode: 31, Time step: 50
# Episode: 31, Time step: 75
# Episode: 31, Time step: 100
# Episode: 31, Time step: 125
# Episode: 31, Time step: 150
# Episode: 31, Time step: 175
# Episode: 32, Time step: 0
# Episode: 32, Time step: 25
# Episode: 32, Time step: 50
# Episode: 32, Time step: 75
# Episode: 32, Time step: 100
# Episode: 32, Time step: 125
# Episode: 32, Time step: 150
# Episode: 32, Time step: 175
# Episode: 33, Time step: 0
# Episode: 33, Time step: 25
# Episode: 33, Time step: 50
# Episode: 33, Time step: 75
# Episode: 33, Time step: 100
# Episode: 33, Time step: 125
# Episode: 33, Time step: 150
# Episode: 33, Time step: 175
# Episode: 34, Time step: 0
# Episode: 34, Time step: 25
# Episode: 34, Time step: 50
# Episode: 34, Time step: 75
# Episode: 34, Time step: 100
# Episode: 34, Time step: 125
# Episode: 34, Time step: 150
# Episode: 34, Time step: 175
# Episode: 35, Time step: 0
# Episode: 35, Time step: 25
# Episode: 35, Time step: 50
# Episode: 35, Time step: 75
# Episode: 35, Time step: 100
# Episode: 35, Time step: 125
# Episode: 35, Time step: 150
# Episode: 35, Time step: 175
# Episode: 36, Time step: 0
# Episode: 36, Time step: 25
# Episode: 36, Time step: 50
# Episode: 36, Time step: 75
# Episode: 36, Time step: 100
# Episode: 36, Time step: 125
# Episode: 36, Time step: 150
# Episode: 36, Time step: 175
# Episode: 37, Time step: 0
# Episode: 37, Time step: 25
# Episode: 37, Time step: 50
# Episode: 37, Time step: 75
# Episode: 37, Time step: 100
# Episode: 37, Time step: 125
# Episode: 37, Time step: 150
# Episode: 37, Time step: 175
# Episode: 38, Time step: 0
# Episode: 38, Time step: 25
# Episode: 38, Time step: 50
# Episode: 38, Time step: 75
# Episode: 38, Time step: 100
# Episode: 38, Time step: 125
# Episode: 38, Time step: 150
# Episode: 38, Time step: 175
# Episode: 39, Time step: 0
# Episode: 39, Time step: 25
# Episode: 39, Time step: 50
# Episode: 39, Time step: 75
# Episode: 39, Time step: 100
# Episode: 39, Time step: 125
# Episode: 39, Time step: 150
# Episode: 39, Time step: 175
# Episode: 40, Time step: 0
# Episode: 40, Time step: 25
# Episode: 40, Time step: 50
# Episode: 40, Time step: 75
# Episode: 40, Time step: 100
# Episode: 40, Time step: 125
# Episode: 40, Time step: 150
# Episode: 40, Time step: 175
# Episode: 41, Time step: 0
# Episode: 41, Time step: 25
# Episode: 41, Time step: 50
# Episode: 41, Time step: 75
# Episode: 41, Time step: 100
# Episode: 41, Time step: 125
# Episode: 41, Time step: 150
# Episode: 41, Time step: 175
# Episode: 42, Time step: 0
# Episode: 42, Time step: 25
# Episode: 42, Time step: 50
# Episode: 42, Time step: 75
# Episode: 42, Time step: 100
# Episode: 42, Time step: 125
# Episode: 42, Time step: 150
# Episode: 42, Time step: 175
# Episode: 43, Time step: 0
# Episode: 43, Time step: 25
# Episode: 43, Time step: 50
# Episode: 43, Time step: 75
# Episode: 43, Time step: 100
# Episode: 43, Time step: 125
# Episode: 43, Time step: 150
# Episode: 43, Time step: 175
# Episode: 44, Time step: 0
# Episode: 44, Time step: 25
# Episode: 44, Time step: 50
# Episode: 44, Time step: 75
# Episode: 44, Time step: 100
# Episode: 44, Time step: 125
# Episode: 44, Time step: 150
# Episode: 44, Time step: 175
# Episode: 45, Time step: 0
# Episode: 45, Time step: 25
# Episode: 45, Time step: 50
# Episode: 45, Time step: 75
# Episode: 45, Time step: 100
# Episode: 45, Time step: 125
# Episode: 45, Time step: 150
# Episode: 45, Time step: 175
# Episode: 46, Time step: 0
# Episode: 46, Time step: 25
# Episode: 46, Time step: 50
# Episode: 46, Time step: 75
# Episode: 46, Time step: 100
# Episode: 46, Time step: 125
# Episode: 46, Time step: 150
# Episode: 46, Time step: 175
# Episode: 47, Time step: 0
# Episode: 47, Time step: 25
# Episode: 47, Time step: 50
# Episode: 47, Time step: 75
# Episode: 47, Time step: 100
# Episode: 47, Time step: 125
# Episode: 47, Time step: 150
# Episode: 47, Time step: 175
# Episode: 48, Time step: 0
# Episode: 48, Time step: 25
# Episode: 48, Time step: 50
# Episode: 48, Time step: 75
# Episode: 48, Time step: 100
# Episode: 48, Time step: 125
# Episode: 48, Time step: 150
# Episode: 48, Time step: 175
# Episode: 49, Time step: 0
# Episode: 49, Time step: 25
# Episode: 49, Time step: 50
# Episode: 49, Time step: 75
# Episode: 49, Time step: 100
# Episode: 49, Time step: 125
# Episode: 49, Time step: 150
# Episode: 49, Time step: 175
# Episode: 50, Time step: 0
# Episode: 50, Time step: 25
# Episode: 50, Time step: 50
# Episode: 50, Time step: 75
# Episode: 50, Time step: 100
# Episode: 50, Time step: 125
# Episode: 50, Time step: 150
# Episode: 50, Time step: 175
# Episode: 51, Time step: 0
# Episode: 51, Time step: 25
# Episode: 51, Time step: 50
# Episode: 51, Time step: 75
# Episode: 51, Time step: 100
# Episode: 51, Time step: 125
# Episode: 51, Time step: 150
# Episode: 51, Time step: 175
# Episode: 52, Time step: 0
# Episode: 52, Time step: 25
# Episode: 52, Time step: 50
# Episode: 52, Time step: 75
# Episode: 52, Time step: 100
# Episode: 52, Time step: 125
# Episode: 52, Time step: 150
# Episode: 52, Time step: 175
# Episode: 53, Time step: 0
# Episode: 53, Time step: 25
# Episode: 53, Time step: 50
# Episode: 53, Time step: 75
# Episode: 53, Time step: 100
# Episode: 53, Time step: 125
# Episode: 53, Time step: 150
# Episode: 53, Time step: 175
# Episode: 54, Time step: 0
# Episode: 54, Time step: 25
# Episode: 54, Time step: 50
# Episode: 54, Time step: 75
# Episode: 54, Time step: 100
# Episode: 54, Time step: 125
# Episode: 54, Time step: 150
# Episode: 54, Time step: 175
# Episode: 55, Time step: 0
# Episode: 55, Time step: 25
# Episode: 55, Time step: 50
# Episode: 55, Time step: 75
# Episode: 55, Time step: 100
# Episode: 55, Time step: 125
# Episode: 55, Time step: 150
# Episode: 55, Time step: 175
# Episode: 56, Time step: 0
# Episode: 56, Time step: 25
# Episode: 56, Time step: 50
# Episode: 56, Time step: 75
# Episode: 56, Time step: 100
# Episode: 56, Time step: 125
# Episode: 56, Time step: 150
# Episode: 56, Time step: 175
# Episode: 57, Time step: 0
# Episode: 57, Time step: 25
# Episode: 57, Time step: 50
# Episode: 57, Time step: 75
# Episode: 57, Time step: 100
# Episode: 57, Time step: 125
# Episode: 57, Time step: 150
# Episode: 57, Time step: 175
# Episode: 58, Time step: 0
# Episode: 58, Time step: 25
# Episode: 58, Time step: 50
# Episode: 58, Time step: 75
# Episode: 58, Time step: 100
# Episode: 58, Time step: 125
# Episode: 58, Time step: 150
# Episode: 58, Time step: 175
# Episode: 59, Time step: 0
# Episode: 59, Time step: 25
# Episode: 59, Time step: 50
# Episode: 59, Time step: 75
# Episode: 59, Time step: 100
# Episode: 59, Time step: 125
# Episode: 59, Time step: 150
# Episode: 59, Time step: 175
# Episode: 60, Time step: 0
# Episode: 60, Time step: 25
# Episode: 60, Time step: 50
# Episode: 60, Time step: 75
# Episode: 60, Time step: 100
# Episode: 60, Time step: 125
# Episode: 60, Time step: 150
# Episode: 60, Time step: 175
# Episode: 61, Time step: 0
# Episode: 61, Time step: 25
# Episode: 61, Time step: 50
# Episode: 61, Time step: 75
# Episode: 61, Time step: 100
# Episode: 61, Time step: 125
# Episode: 61, Time step: 150
# Episode: 61, Time step: 175
# Episode: 62, Time step: 0
# Episode: 62, Time step: 25
# Episode: 62, Time step: 50
# Episode: 62, Time step: 75
# Episode: 62, Time step: 100
# Episode: 62, Time step: 125
# Episode: 62, Time step: 150
# Episode: 62, Time step: 175
# Episode: 63, Time step: 0
# Episode: 63, Time step: 25
# Episode: 63, Time step: 50
# Episode: 63, Time step: 75
# Episode: 63, Time step: 100
# Episode: 63, Time step: 125
# Episode: 63, Time step: 150
# Episode: 63, Time step: 175
# Episode: 64, Time step: 0
# Episode: 64, Time step: 25
# Episode: 64, Time step: 50
# Episode: 64, Time step: 75
# Episode: 64, Time step: 100
# Episode: 64, Time step: 125
# Episode: 64, Time step: 150
# Episode: 64, Time step: 175
# Episode: 65, Time step: 0
# Episode: 65, Time step: 25
# Episode: 65, Time step: 50
# Episode: 65, Time step: 75
# Episode: 65, Time step: 100
# Episode: 65, Time step: 125
# Episode: 65, Time step: 150
# Episode: 65, Time step: 175
# Episode: 66, Time step: 0
# Episode: 66, Time step: 25
# Episode: 66, Time step: 50
# Episode: 66, Time step: 75
# Episode: 66, Time step: 100
# Episode: 66, Time step: 125
# Episode: 66, Time step: 150
# Episode: 66, Time step: 175
# Episode: 67, Time step: 0
# Episode: 67, Time step: 25
# Episode: 67, Time step: 50
# Episode: 67, Time step: 75
# Episode: 67, Time step: 100
# Episode: 67, Time step: 125
# Episode: 67, Time step: 150
# Episode: 67, Time step: 175
# Episode: 68, Time step: 0
# Episode: 68, Time step: 25
# Episode: 68, Time step: 50
# Episode: 68, Time step: 75
# Episode: 68, Time step: 100
# Episode: 68, Time step: 125
# Episode: 68, Time step: 150
# Episode: 68, Time step: 175
# Episode: 69, Time step: 0
# Episode: 69, Time step: 25
# Episode: 69, Time step: 50
# Episode: 69, Time step: 75
# Episode: 69, Time step: 100
# Episode: 69, Time step: 125
# Episode: 69, Time step: 150
# Episode: 69, Time step: 175
# Episode: 70, Time step: 0
# Episode: 70, Time step: 25
# Episode: 70, Time step: 50
# Episode: 70, Time step: 75
# Episode: 70, Time step: 100
# Episode: 70, Time step: 125
# Episode: 70, Time step: 150
# Episode: 70, Time step: 175
# Episode: 71, Time step: 0
# Episode: 71, Time step: 25
# Episode: 71, Time step: 50
# Episode: 71, Time step: 75
# Episode: 71, Time step: 100
# Episode: 71, Time step: 125
# Episode: 71, Time step: 150
# Episode: 71, Time step: 175
# Episode: 72, Time step: 0
# Episode: 72, Time step: 25
# Episode: 72, Time step: 50
# Episode: 72, Time step: 75
# Episode: 72, Time step: 100
# Episode: 72, Time step: 125
# Episode: 72, Time step: 150
# Episode: 72, Time step: 175
# Episode: 73, Time step: 0
# Episode: 73, Time step: 25
# Episode: 73, Time step: 50
# Episode: 73, Time step: 75
# Episode: 73, Time step: 100
# Episode: 73, Time step: 125
# Episode: 73, Time step: 150
# Episode: 73, Time step: 175
# Episode: 74, Time step: 0
# Episode: 74, Time step: 25
# Episode: 74, Time step: 50
# Episode: 74, Time step: 75
# Episode: 74, Time step: 100
# Episode: 74, Time step: 125
# Episode: 74, Time step: 150
# Episode: 74, Time step: 175
# Episode: 75, Time step: 0
# Episode: 75, Time step: 25
# Episode: 75, Time step: 50
# Episode: 75, Time step: 75
# Episode: 75, Time step: 100
# Episode: 75, Time step: 125
# Episode: 75, Time step: 150
# Episode: 75, Time step: 175
# Episode: 76, Time step: 0
# Episode: 76, Time step: 25
# Episode: 76, Time step: 50
# Episode: 76, Time step: 75
# Episode: 76, Time step: 100
# Episode: 76, Time step: 125
# Episode: 76, Time step: 150
# Episode: 76, Time step: 175
# Episode: 77, Time step: 0
# Episode: 77, Time step: 25
# Episode: 77, Time step: 50
# Episode: 77, Time step: 75
# Episode: 77, Time step: 100
# Episode: 77, Time step: 125
# Episode: 77, Time step: 150
# Episode: 77, Time step: 175
# Episode: 78, Time step: 0
# Episode: 78, Time step: 25
# Episode: 78, Time step: 50
# Episode: 78, Time step: 75
# Episode: 78, Time step: 100
# Episode: 78, Time step: 125
# Episode: 78, Time step: 150
# Episode: 78, Time step: 175
# Episode: 79, Time step: 0
# Episode: 79, Time step: 25
# Episode: 79, Time step: 50
# Episode: 79, Time step: 75
# Episode: 79, Time step: 100
# Episode: 79, Time step: 125
# Episode: 79, Time step: 150
# Episode: 79, Time step: 175
# Episode: 80, Time step: 0
# Episode: 80, Time step: 25
# Episode: 80, Time step: 50
# Episode: 80, Time step: 75
# Episode: 80, Time step: 100
# Episode: 80, Time step: 125
# Episode: 80, Time step: 150
# Episode: 80, Time step: 175
# Episode: 81, Time step: 0
# Episode: 81, Time step: 25
# Episode: 81, Time step: 50
# Episode: 81, Time step: 75
# Episode: 81, Time step: 100
# Episode: 81, Time step: 125
# Episode: 81, Time step: 150
# Episode: 81, Time step: 175
# Episode: 82, Time step: 0
# Episode: 82, Time step: 25
# Episode: 82, Time step: 50
# Episode: 82, Time step: 75
# Episode: 82, Time step: 100
# Episode: 82, Time step: 125
# Episode: 82, Time step: 150
# Episode: 82, Time step: 175
# Episode: 83, Time step: 0
# Episode: 83, Time step: 25
# Episode: 83, Time step: 50
# Episode: 83, Time step: 75
# Episode: 83, Time step: 100
# Episode: 83, Time step: 125
# Episode: 83, Time step: 150
# Episode: 83, Time step: 175
# Episode: 84, Time step: 0
# Episode: 84, Time step: 25
# Episode: 84, Time step: 50
# Episode: 84, Time step: 75
# Episode: 84, Time step: 100
# Episode: 84, Time step: 125
# Episode: 84, Time step: 150
# Episode: 84, Time step: 175
# Episode: 85, Time step: 0
# Episode: 85, Time step: 25
# Episode: 85, Time step: 50
# Episode: 85, Time step: 75
# Episode: 85, Time step: 100
# Episode: 85, Time step: 125
# Episode: 85, Time step: 150
# Episode: 85, Time step: 175
# Episode: 86, Time step: 0
# Episode: 86, Time step: 25
# Episode: 86, Time step: 50
# Episode: 86, Time step: 75
# Episode: 86, Time step: 100
# Episode: 86, Time step: 125
# Episode: 86, Time step: 150
# Episode: 86, Time step: 175
# Episode: 87, Time step: 0
# Episode: 87, Time step: 25
# Episode: 87, Time step: 50
# Episode: 87, Time step: 75
# Episode: 87, Time step: 100
# Episode: 87, Time step: 125
# Episode: 87, Time step: 150
# Episode: 87, Time step: 175
# Episode: 88, Time step: 0
# Episode: 88, Time step: 25
# Episode: 88, Time step: 50
# Episode: 88, Time step: 75
# Episode: 88, Time step: 100
# Episode: 88, Time step: 125
# Episode: 88, Time step: 150
# Episode: 88, Time step: 175
# Episode: 89, Time step: 0
# Episode: 89, Time step: 25
# Episode: 89, Time step: 50
# Episode: 89, Time step: 75
# Episode: 89, Time step: 100
# Episode: 89, Time step: 125
# Episode: 89, Time step: 150
# Episode: 89, Time step: 175
# Episode: 90, Time step: 0
# Episode: 90, Time step: 25
# Episode: 90, Time step: 50
# Episode: 90, Time step: 75
# Episode: 90, Time step: 100
# Episode: 90, Time step: 125
# Episode: 90, Time step: 150
# Episode: 90, Time step: 175
# Episode: 91, Time step: 0
# Episode: 91, Time step: 25
# Episode: 91, Time step: 50
# Episode: 91, Time step: 75
# Episode: 91, Time step: 100
# Episode: 91, Time step: 125
# Episode: 91, Time step: 150
# Episode: 91, Time step: 175
# Episode: 92, Time step: 0
# Episode: 92, Time step: 25
# Episode: 92, Time step: 50
# Episode: 92, Time step: 75
# Episode: 92, Time step: 100
# Episode: 92, Time step: 125
# Episode: 92, Time step: 150
# Episode: 92, Time step: 175
# Episode: 93, Time step: 0
# Episode: 93, Time step: 25
# Episode: 93, Time step: 50
# Episode: 93, Time step: 75
# Episode: 93, Time step: 100
# Episode: 93, Time step: 125
# Episode: 93, Time step: 150
# Episode: 93, Time step: 175
# Episode: 94, Time step: 0
# Episode: 94, Time step: 25
# Episode: 94, Time step: 50
# Episode: 94, Time step: 75
# Episode: 94, Time step: 100
# Episode: 94, Time step: 125
# Episode: 94, Time step: 150
# Episode: 94, Time step: 175
# Episode: 95, Time step: 0
# Episode: 95, Time step: 25
# Episode: 95, Time step: 50
# Episode: 95, Time step: 75
# Episode: 95, Time step: 100
# Episode: 95, Time step: 125
# Episode: 95, Time step: 150
# Episode: 95, Time step: 175
# Episode: 96, Time step: 0
# Episode: 96, Time step: 25
# Episode: 96, Time step: 50
# Episode: 96, Time step: 75
# Episode: 96, Time step: 100
# Episode: 96, Time step: 125
# Episode: 96, Time step: 150
# Episode: 96, Time step: 175
# Episode: 97, Time step: 0
# Episode: 97, Time step: 25
# Episode: 97, Time step: 50
# Episode: 97, Time step: 75
# Episode: 97, Time step: 100
# Episode: 97, Time step: 125
# Episode: 97, Time step: 150
# Episode: 97, Time step: 175
# Episode: 98, Time step: 0
# Episode: 98, Time step: 25
# Episode: 98, Time step: 50
# Episode: 98, Time step: 75
# Episode: 98, Time step: 100
# Episode: 98, Time step: 125
# Episode: 98, Time step: 150
# Episode: 98, Time step: 175
# Episode: 99, Time step: 0
# Episode: 99, Time step: 25
# Episode: 99, Time step: 50
# Episode: 99, Time step: 75
# Episode: 99, Time step: 100
# Episode: 99, Time step: 125
# Episode: 99, Time step: 150
# Episode: 99, Time step: 175
# Episode: 100, Time step: 0
# Episode: 100, Time step: 25
# Episode: 100, Time step: 50
# Episode: 100, Time step: 75
# Episode: 100, Time step: 100
# Episode: 100, Time step: 125
# Episode: 100, Time step: 150
# Episode: 100, Time step: 175
# Episode: 101, Time step: 0
# Episode: 101, Time step: 25
# Episode: 101, Time step: 50
# Episode: 101, Time step: 75
# Episode: 101, Time step: 100
# Episode: 101, Time step: 125
# Episode: 101, Time step: 150
# Episode: 101, Time step: 175
# Episode: 102, Time step: 0
# Episode: 102, Time step: 25
# Episode: 102, Time step: 50
# Episode: 102, Time step: 75
# Episode: 102, Time step: 100
# Episode: 102, Time step: 125
# Episode: 102, Time step: 150
# Episode: 102, Time step: 175
# Episode: 103, Time step: 0
# Episode: 103, Time step: 25
# Episode: 103, Time step: 50
# Episode: 103, Time step: 75
# Episode: 103, Time step: 100
# Episode: 103, Time step: 125
# Episode: 103, Time step: 150
# Episode: 103, Time step: 175
# Episode: 104, Time step: 0
# Episode: 104, Time step: 25
# Episode: 104, Time step: 50
# Episode: 104, Time step: 75
# Episode: 104, Time step: 100
# Episode: 104, Time step: 125
# Episode: 104, Time step: 150
# Episode: 104, Time step: 175
# Episode: 105, Time step: 0
# Episode: 105, Time step: 25
# Episode: 105, Time step: 50
# Episode: 105, Time step: 75
# Episode: 105, Time step: 100
# Episode: 105, Time step: 125
# Episode: 105, Time step: 150
# Episode: 105, Time step: 175
# Episode: 106, Time step: 0
# Episode: 106, Time step: 25
# Episode: 106, Time step: 50
# Episode: 106, Time step: 75
# Episode: 106, Time step: 100
# Episode: 106, Time step: 125
# Episode: 106, Time step: 150
# Episode: 106, Time step: 175
# Episode: 107, Time step: 0
# Episode: 107, Time step: 25
# Episode: 107, Time step: 50
# Episode: 107, Time step: 75
# Episode: 107, Time step: 100
# Episode: 107, Time step: 125
# Episode: 107, Time step: 150
# Episode: 107, Time step: 175
# Episode: 108, Time step: 0
# Episode: 108, Time step: 25
# Episode: 108, Time step: 50
# Episode: 108, Time step: 75
# Episode: 108, Time step: 100
# Episode: 108, Time step: 125
# Episode: 108, Time step: 150
# Episode: 108, Time step: 175
# Episode: 109, Time step: 0
# Episode: 109, Time step: 25
# Episode: 109, Time step: 50
# Episode: 109, Time step: 75
# Episode: 109, Time step: 100
# Episode: 109, Time step: 125
# Episode: 109, Time step: 150
# Episode: 109, Time step: 175
# Episode: 110, Time step: 0
# Episode: 110, Time step: 25
# Episode: 110, Time step: 50
# Episode: 110, Time step: 75
# Episode: 110, Time step: 100
# Episode: 110, Time step: 125
# Episode: 110, Time step: 150
# Episode: 110, Time step: 175
# Episode: 111, Time step: 0
# Episode: 111, Time step: 25
# Episode: 111, Time step: 50
# Episode: 111, Time step: 75
# Episode: 111, Time step: 100
# Episode: 111, Time step: 125
# Episode: 111, Time step: 150
# Episode: 111, Time step: 175
# Episode: 112, Time step: 0
# Episode: 112, Time step: 25
# Episode: 112, Time step: 50
# Episode: 112, Time step: 75
# Episode: 112, Time step: 100
# Episode: 112, Time step: 125
# Episode: 112, Time step: 150
# Episode: 112, Time step: 175
# Episode: 113, Time step: 0
# Episode: 113, Time step: 25
# Episode: 113, Time step: 50
# Episode: 113, Time step: 75
# Episode: 113, Time step: 100
# Episode: 113, Time step: 125
# Episode: 113, Time step: 150
# Episode: 113, Time step: 175
# Episode: 114, Time step: 0
# Episode: 114, Time step: 25
# Episode: 114, Time step: 50
# Episode: 114, Time step: 75
# Episode: 114, Time step: 100
# Episode: 114, Time step: 125
# Episode: 114, Time step: 150
# Episode: 114, Time step: 175
# Episode: 115, Time step: 0
# Episode: 115, Time step: 25
# Episode: 115, Time step: 50
# Episode: 115, Time step: 75
# Episode: 115, Time step: 100
# Episode: 115, Time step: 125
# Episode: 115, Time step: 150
# Episode: 115, Time step: 175
# Episode: 116, Time step: 0
# Episode: 116, Time step: 25
# Episode: 116, Time step: 50
# Episode: 116, Time step: 75
# Episode: 116, Time step: 100
# Episode: 116, Time step: 125
# Episode: 116, Time step: 150
# Episode: 116, Time step: 175
# Episode: 117, Time step: 0
# Episode: 117, Time step: 25
# Episode: 117, Time step: 50
# Episode: 117, Time step: 75
# Episode: 117, Time step: 100
# Episode: 117, Time step: 125
# Episode: 117, Time step: 150
# Episode: 117, Time step: 175
# Episode: 118, Time step: 0
# Episode: 118, Time step: 25
# Episode: 118, Time step: 50
# Episode: 118, Time step: 75
# Episode: 118, Time step: 100
# Episode: 118, Time step: 125
# Episode: 118, Time step: 150
# Episode: 118, Time step: 175
# Episode: 119, Time step: 0
# Episode: 119, Time step: 25
# Episode: 119, Time step: 50
# Episode: 119, Time step: 75
# Episode: 119, Time step: 100
# Episode: 119, Time step: 125
# Episode: 119, Time step: 150
# Episode: 119, Time step: 175
# Episode: 120, Time step: 0
# Episode: 120, Time step: 25
# Episode: 120, Time step: 50
# Episode: 120, Time step: 75
# Episode: 120, Time step: 100
# Episode: 120, Time step: 125
# Episode: 120, Time step: 150
# Episode: 120, Time step: 175
# Episode: 121, Time step: 0
# Episode: 121, Time step: 25
# Episode: 121, Time step: 50
# Episode: 121, Time step: 75
# Episode: 121, Time step: 100
# Episode: 121, Time step: 125
# Episode: 121, Time step: 150
# Episode: 121, Time step: 175
# Episode: 122, Time step: 0
# Episode: 122, Time step: 25
# Episode: 122, Time step: 50
# Episode: 122, Time step: 75
# Episode: 122, Time step: 100
# Episode: 122, Time step: 125
# Episode: 122, Time step: 150
# Episode: 122, Time step: 175
# Episode: 123, Time step: 0
# Episode: 123, Time step: 25
# Episode: 123, Time step: 50
# Episode: 123, Time step: 75
# Episode: 123, Time step: 100
# Episode: 123, Time step: 125
# Episode: 123, Time step: 150
# Episode: 123, Time step: 175
# Episode: 124, Time step: 0
# Episode: 124, Time step: 25
# Episode: 124, Time step: 50
# Episode: 124, Time step: 75
# Episode: 124, Time step: 100
# Episode: 124, Time step: 125
# Episode: 124, Time step: 150
# Episode: 124, Time step: 175
# Episode: 125, Time step: 0
# Episode: 125, Time step: 25
# Episode: 125, Time step: 50
# Episode: 125, Time step: 75
# Episode: 125, Time step: 100
# Episode: 125, Time step: 125
# Episode: 125, Time step: 150
# Episode: 125, Time step: 175
# Episode: 126, Time step: 0
# Episode: 126, Time step: 25
# Episode: 126, Time step: 50
# Episode: 126, Time step: 75
# Episode: 126, Time step: 100
# Episode: 126, Time step: 125
# Episode: 126, Time step: 150
# Episode: 126, Time step: 175
# Episode: 127, Time step: 0
# Episode: 127, Time step: 25
# Episode: 127, Time step: 50
# Episode: 127, Time step: 75
# Episode: 127, Time step: 100
# Episode: 127, Time step: 125
# Episode: 127, Time step: 150
# Episode: 127, Time step: 175
# Episode: 128, Time step: 0
# Episode: 128, Time step: 25
# Episode: 128, Time step: 50
# Episode: 128, Time step: 75
# Episode: 128, Time step: 100
# Episode: 128, Time step: 125
# Episode: 128, Time step: 150
# Episode: 128, Time step: 175
# Episode: 129, Time step: 0
# Episode: 129, Time step: 25
# Episode: 129, Time step: 50
# Episode: 129, Time step: 75
# Episode: 129, Time step: 100
# Episode: 129, Time step: 125
# Episode: 129, Time step: 150
# Episode: 129, Time step: 175
# Episode: 130, Time step: 0
# Episode: 130, Time step: 25
# Episode: 130, Time step: 50
# Episode: 130, Time step: 75
# Episode: 130, Time step: 100
# Episode: 130, Time step: 125
# Episode: 130, Time step: 150
# Episode: 130, Time step: 175
# Episode: 131, Time step: 0
# Episode: 131, Time step: 25
# Episode: 131, Time step: 50
# Episode: 131, Time step: 75
# Episode: 131, Time step: 100
# Episode: 131, Time step: 125
# Episode: 131, Time step: 150
# Episode: 131, Time step: 175
# Episode: 132, Time step: 0
# Episode: 132, Time step: 25
# Episode: 132, Time step: 50
# Episode: 132, Time step: 75
# Episode: 132, Time step: 100
# Episode: 132, Time step: 125
# Episode: 132, Time step: 150
# Episode: 132, Time step: 175
# Episode: 133, Time step: 0
# Episode: 133, Time step: 25
# Episode: 133, Time step: 50
# Episode: 133, Time step: 75
# Episode: 133, Time step: 100
# Episode: 133, Time step: 125
# Episode: 133, Time step: 150
# Episode: 133, Time step: 175
# Episode: 134, Time step: 0
# Episode: 134, Time step: 25
# Episode: 134, Time step: 50
# Episode: 134, Time step: 75
# Episode: 134, Time step: 100
# Episode: 134, Time step: 125
# Episode: 134, Time step: 150
# Episode: 134, Time step: 175
# Episode: 135, Time step: 0
# Episode: 135, Time step: 25
# Episode: 135, Time step: 50
# Episode: 135, Time step: 75
# Episode: 135, Time step: 100
# Episode: 135, Time step: 125
# Episode: 135, Time step: 150
# Episode: 135, Time step: 175
# Episode: 136, Time step: 0
# Episode: 136, Time step: 25
# Episode: 136, Time step: 50
# Episode: 136, Time step: 75
# Episode: 136, Time step: 100
# Episode: 136, Time step: 125
# Episode: 136, Time step: 150
# Episode: 136, Time step: 175
# Episode: 137, Time step: 0
# Episode: 137, Time step: 25
# Episode: 137, Time step: 50
# Episode: 137, Time step: 75
# Episode: 137, Time step: 100
# Episode: 137, Time step: 125
# Episode: 137, Time step: 150
# Episode: 137, Time step: 175
# Episode: 138, Time step: 0
# Episode: 138, Time step: 25
# Episode: 138, Time step: 50
# Episode: 138, Time step: 75
# Episode: 138, Time step: 100
# Episode: 138, Time step: 125
# Episode: 138, Time step: 150
# Episode: 138, Time step: 175
# Episode: 139, Time step: 0
# Episode: 139, Time step: 25
# Episode: 139, Time step: 50
# Episode: 139, Time step: 75
# Episode: 139, Time step: 100
# Episode: 139, Time step: 125
# Episode: 139, Time step: 150
# Episode: 139, Time step: 175
# Episode: 140, Time step: 0
# Episode: 140, Time step: 25
# Episode: 140, Time step: 50
# Episode: 140, Time step: 75
# Episode: 140, Time step: 100
# Episode: 140, Time step: 125
# Episode: 140, Time step: 150
# Episode: 140, Time step: 175
# Episode: 141, Time step: 0
# Episode: 141, Time step: 25
# Episode: 141, Time step: 50
# Episode: 141, Time step: 75
# Episode: 141, Time step: 100
# Episode: 141, Time step: 125
# Episode: 141, Time step: 150
# Episode: 141, Time step: 175
# Episode: 142, Time step: 0
# Episode: 142, Time step: 25
# Episode: 142, Time step: 50
# Episode: 142, Time step: 75
# Episode: 142, Time step: 100
# Episode: 142, Time step: 125
# Episode: 142, Time step: 150
# Episode: 142, Time step: 175
# Episode: 143, Time step: 0
# Episode: 143, Time step: 25
# Episode: 143, Time step: 50
# Episode: 143, Time step: 75
# Episode: 143, Time step: 100
# Episode: 143, Time step: 125
# Episode: 143, Time step: 150
# Episode: 143, Time step: 175
# Episode: 144, Time step: 0
# Episode: 144, Time step: 25
# Episode: 144, Time step: 50
# Episode: 144, Time step: 75
# Episode: 144, Time step: 100
# Episode: 144, Time step: 125
# Episode: 144, Time step: 150
# Episode: 144, Time step: 175
# Episode: 145, Time step: 0
# Episode: 145, Time step: 25
# Episode: 145, Time step: 50
# Episode: 145, Time step: 75
# Episode: 145, Time step: 100
# Episode: 145, Time step: 125
# Episode: 145, Time step: 150
# Episode: 145, Time step: 175
# Episode: 146, Time step: 0
# Episode: 146, Time step: 25
# Episode: 146, Time step: 50
# Episode: 146, Time step: 75
# Episode: 146, Time step: 100
# Episode: 146, Time step: 125
# Episode: 146, Time step: 150
# Episode: 146, Time step: 175
# Episode: 147, Time step: 0
# Episode: 147, Time step: 25
# Episode: 147, Time step: 50
# Episode: 147, Time step: 75
# Episode: 147, Time step: 100
# Episode: 147, Time step: 125
# Episode: 147, Time step: 150
# Episode: 147, Time step: 175
# Episode: 148, Time step: 0
# Episode: 148, Time step: 25
# Episode: 148, Time step: 50
# Episode: 148, Time step: 75
# Episode: 148, Time step: 100
# Episode: 148, Time step: 125
# Episode: 148, Time step: 150
# Episode: 148, Time step: 175
# Episode: 149, Time step: 0
# Episode: 149, Time step: 25
# Episode: 149, Time step: 50
# Episode: 149, Time step: 75
# Episode: 149, Time step: 100
# Episode: 149, Time step: 125
# Episode: 149, Time step: 150
# Episode: 149, Time step: 175
# Episode: 150, Time step: 0
# Episode: 150, Time step: 25
# Episode: 150, Time step: 50
# Episode: 150, Time step: 75
# Episode: 150, Time step: 100
# Episode: 150, Time step: 125
# Episode: 150, Time step: 150
# Episode: 150, Time step: 175
# Episode: 151, Time step: 0
# Episode: 151, Time step: 25
# Episode: 151, Time step: 50
# Episode: 151, Time step: 75
# Episode: 151, Time step: 100
# Episode: 151, Time step: 125
# Episode: 151, Time step: 150
# Episode: 151, Time step: 175
# Episode: 152, Time step: 0
# Episode: 152, Time step: 25
# Episode: 152, Time step: 50
# Episode: 152, Time step: 75
# Episode: 152, Time step: 100
# Episode: 152, Time step: 125
# Episode: 152, Time step: 150
# Episode: 152, Time step: 175
# Episode: 153, Time step: 0
# Episode: 153, Time step: 25
# Episode: 153, Time step: 50
# Episode: 153, Time step: 75
# Episode: 153, Time step: 100
# Episode: 153, Time step: 125
# Episode: 153, Time step: 150
# Episode: 153, Time step: 175
# Episode: 154, Time step: 0
# Episode: 154, Time step: 25
# Episode: 154, Time step: 50
# Episode: 154, Time step: 75
# Episode: 154, Time step: 100
# Episode: 154, Time step: 125
# Episode: 154, Time step: 150
# Episode: 154, Time step: 175
# Episode: 155, Time step: 0
# Episode: 155, Time step: 25
# Episode: 155, Time step: 50
# Episode: 155, Time step: 75
# Episode: 155, Time step: 100
# Episode: 155, Time step: 125
# Episode: 155, Time step: 150
# Episode: 155, Time step: 175
# Episode: 156, Time step: 0
# Episode: 156, Time step: 25
# Episode: 156, Time step: 50
# Episode: 156, Time step: 75
# Episode: 156, Time step: 100
# Episode: 156, Time step: 125
# Episode: 156, Time step: 150
# Episode: 156, Time step: 175
# Episode: 157, Time step: 0
# Episode: 157, Time step: 25
# Episode: 157, Time step: 50
# Episode: 157, Time step: 75
# Episode: 157, Time step: 100
# Episode: 157, Time step: 125
# Episode: 157, Time step: 150
# Episode: 157, Time step: 175
# Episode: 158, Time step: 0
# Episode: 158, Time step: 25
# Episode: 158, Time step: 50
# Episode: 158, Time step: 75
# Episode: 158, Time step: 100
# Episode: 158, Time step: 125
# Episode: 158, Time step: 150
# Episode: 158, Time step: 175
# Episode: 159, Time step: 0
# Episode: 159, Time step: 25
# Episode: 159, Time step: 50
# Episode: 159, Time step: 75
# Episode: 159, Time step: 100
# Episode: 159, Time step: 125
# Episode: 159, Time step: 150
# Episode: 159, Time step: 175
# Episode: 160, Time step: 0
# Episode: 160, Time step: 25
# Episode: 160, Time step: 50
# Episode: 160, Time step: 75
# Episode: 160, Time step: 100
# Episode: 160, Time step: 125
# Episode: 160, Time step: 150
# Episode: 160, Time step: 175
# Episode: 161, Time step: 0
# Episode: 161, Time step: 25
# Episode: 161, Time step: 50
# Episode: 161, Time step: 75
# Episode: 161, Time step: 100
# Episode: 161, Time step: 125
# Episode: 161, Time step: 150
# Episode: 161, Time step: 175
# Episode: 162, Time step: 0
# Episode: 162, Time step: 25
# Episode: 162, Time step: 50
# Episode: 162, Time step: 75
# Episode: 162, Time step: 100
# Episode: 162, Time step: 125
# Episode: 162, Time step: 150
# Episode: 162, Time step: 175
# Episode: 163, Time step: 0
# Episode: 163, Time step: 25
# Episode: 163, Time step: 50
# Episode: 163, Time step: 75
# Episode: 163, Time step: 100
# Episode: 163, Time step: 125
# Episode: 163, Time step: 150
# Episode: 163, Time step: 175
# Episode: 164, Time step: 0
# Episode: 164, Time step: 25
# Episode: 164, Time step: 50
# Episode: 164, Time step: 75
# Episode: 164, Time step: 100
# Episode: 164, Time step: 125
# Episode: 164, Time step: 150
# Episode: 164, Time step: 175
# Episode: 165, Time step: 0
# Episode: 165, Time step: 25
# Episode: 165, Time step: 50
# Episode: 165, Time step: 75
# Episode: 165, Time step: 100
# Episode: 165, Time step: 125
# Episode: 165, Time step: 150
# Episode: 165, Time step: 175
# Episode: 166, Time step: 0
# Episode: 166, Time step: 25
# Episode: 166, Time step: 50
# Episode: 166, Time step: 75
# Episode: 166, Time step: 100
# Episode: 166, Time step: 125
# Episode: 166, Time step: 150
# Episode: 166, Time step: 175
# Episode: 167, Time step: 0
# Episode: 167, Time step: 25
# Episode: 167, Time step: 50
# Episode: 167, Time step: 75
# Episode: 167, Time step: 100
# Episode: 167, Time step: 125
# Episode: 167, Time step: 150
# Episode: 167, Time step: 175
# Episode: 168, Time step: 0
# Episode: 168, Time step: 25
# Episode: 168, Time step: 50
# Episode: 168, Time step: 75
# Episode: 168, Time step: 100
# Episode: 168, Time step: 125
# Episode: 168, Time step: 150
# Episode: 168, Time step: 175
# Episode: 169, Time step: 0
# Episode: 169, Time step: 25
# Episode: 169, Time step: 50
# Episode: 169, Time step: 75
# Episode: 169, Time step: 100
# Episode: 169, Time step: 125
# Episode: 169, Time step: 150
# Episode: 169, Time step: 175
# Episode: 170, Time step: 0
# Episode: 170, Time step: 25
# Episode: 170, Time step: 50
# Episode: 170, Time step: 75
# Episode: 170, Time step: 100
# Episode: 170, Time step: 125
# Episode: 170, Time step: 150
# Episode: 170, Time step: 175
# Episode: 171, Time step: 0
# Episode: 171, Time step: 25
# Episode: 171, Time step: 50
# Episode: 171, Time step: 75
# Episode: 171, Time step: 100
# Episode: 171, Time step: 125
# Episode: 171, Time step: 150
# Episode: 171, Time step: 175
# Episode: 172, Time step: 0
# Episode: 172, Time step: 25
# Episode: 172, Time step: 50
# Episode: 172, Time step: 75
# Episode: 172, Time step: 100
# Episode: 172, Time step: 125
# Episode: 172, Time step: 150
# Episode: 172, Time step: 175
# Episode: 173, Time step: 0
# Episode: 173, Time step: 25
# Episode: 173, Time step: 50
# Episode: 173, Time step: 75
# Episode: 173, Time step: 100
# Episode: 173, Time step: 125
# Episode: 173, Time step: 150
# Episode: 173, Time step: 175
# Episode: 174, Time step: 0
# Episode: 174, Time step: 25
# Episode: 174, Time step: 50
# Episode: 174, Time step: 75
# Episode: 174, Time step: 100
# Episode: 174, Time step: 125
# Episode: 174, Time step: 150
# Episode: 174, Time step: 175
# Episode: 175, Time step: 0
# Episode: 175, Time step: 25
# Episode: 175, Time step: 50
# Episode: 175, Time step: 75
# Episode: 175, Time step: 100
# Episode: 175, Time step: 125
# Episode: 175, Time step: 150
# Episode: 175, Time step: 175
# Episode: 176, Time step: 0
# Episode: 176, Time step: 25
# Episode: 176, Time step: 50
# Episode: 176, Time step: 75
# Episode: 176, Time step: 100
# Episode: 176, Time step: 125
# Episode: 176, Time step: 150
# Episode: 176, Time step: 175
# Episode: 177, Time step: 0
# Episode: 177, Time step: 25
# Episode: 177, Time step: 50
# Episode: 177, Time step: 75
# Episode: 177, Time step: 100
# Episode: 177, Time step: 125
# Episode: 177, Time step: 150
# Episode: 177, Time step: 175
# Episode: 178, Time step: 0
# Episode: 178, Time step: 25
# Episode: 178, Time step: 50
# Episode: 178, Time step: 75
# Episode: 178, Time step: 100
# Episode: 178, Time step: 125
# Episode: 178, Time step: 150
# Episode: 178, Time step: 175
# Episode: 179, Time step: 0
# Episode: 179, Time step: 25
# Episode: 179, Time step: 50
# Episode: 179, Time step: 75
# Episode: 179, Time step: 100
# Episode: 179, Time step: 125
# Episode: 179, Time step: 150
# Episode: 179, Time step: 175
# Episode: 180, Time step: 0
# Episode: 180, Time step: 25
# Episode: 180, Time step: 50
# Episode: 180, Time step: 75
# Episode: 180, Time step: 100
# Episode: 180, Time step: 125
# Episode: 180, Time step: 150
# Episode: 180, Time step: 175
# Episode: 181, Time step: 0
# Episode: 181, Time step: 25
# Episode: 181, Time step: 50
# Episode: 181, Time step: 75
# Episode: 181, Time step: 100
# Episode: 181, Time step: 125
# Episode: 181, Time step: 150
# Episode: 181, Time step: 175
# Episode: 182, Time step: 0
# Episode: 182, Time step: 25
# Episode: 182, Time step: 50
# Episode: 182, Time step: 75
# Episode: 182, Time step: 100
# Episode: 182, Time step: 125
# Episode: 182, Time step: 150
# Episode: 182, Time step: 175
# Episode: 183, Time step: 0
# Episode: 183, Time step: 25
# Episode: 183, Time step: 50
# Episode: 183, Time step: 75
# Episode: 183, Time step: 100
# Episode: 183, Time step: 125
# Episode: 183, Time step: 150
# Episode: 183, Time step: 175
# Episode: 184, Time step: 0
# Episode: 184, Time step: 25
# Episode: 184, Time step: 50
# Episode: 184, Time step: 75
# Episode: 184, Time step: 100
# Episode: 184, Time step: 125
# Episode: 184, Time step: 150
# Episode: 184, Time step: 175
# Episode: 185, Time step: 0
# Episode: 185, Time step: 25
# Episode: 185, Time step: 50
# Episode: 185, Time step: 75
# Episode: 185, Time step: 100
# Episode: 185, Time step: 125
# Episode: 185, Time step: 150
# Episode: 185, Time step: 175
# Episode: 186, Time step: 0
# Episode: 186, Time step: 25
# Episode: 186, Time step: 50
# Episode: 186, Time step: 75
# Episode: 186, Time step: 100
# Episode: 186, Time step: 125
# Episode: 186, Time step: 150
# Episode: 186, Time step: 175
# Episode: 187, Time step: 0
# Episode: 187, Time step: 25
# Episode: 187, Time step: 50
# Episode: 187, Time step: 75
# Episode: 187, Time step: 100
# Episode: 187, Time step: 125
# Episode: 187, Time step: 150
# Episode: 187, Time step: 175
# Episode: 188, Time step: 0
# Episode: 188, Time step: 25
# Episode: 188, Time step: 50
# Episode: 188, Time step: 75
# Episode: 188, Time step: 100
# Episode: 188, Time step: 125
# Episode: 188, Time step: 150
# Episode: 188, Time step: 175
# Episode: 189, Time step: 0
# Episode: 189, Time step: 25
# Episode: 189, Time step: 50
# Episode: 189, Time step: 75
# Episode: 189, Time step: 100
# Episode: 189, Time step: 125
# Episode: 189, Time step: 150
# Episode: 189, Time step: 175
# Episode: 190, Time step: 0
# Episode: 190, Time step: 25
# Episode: 190, Time step: 50
# Episode: 190, Time step: 75
# Episode: 190, Time step: 100
# Episode: 190, Time step: 125
# Episode: 190, Time step: 150
# Episode: 190, Time step: 175
# Episode: 191, Time step: 0
# Episode: 191, Time step: 25
# Episode: 191, Time step: 50
# Episode: 191, Time step: 75
# Episode: 191, Time step: 100
# Episode: 191, Time step: 125
# Episode: 191, Time step: 150
# Episode: 191, Time step: 175
# Episode: 192, Time step: 0
# Episode: 192, Time step: 25
# Episode: 192, Time step: 50
# Episode: 192, Time step: 75
# Episode: 192, Time step: 100
# Episode: 192, Time step: 125
# Episode: 192, Time step: 150
# Episode: 192, Time step: 175
# Episode: 193, Time step: 0
# Episode: 193, Time step: 25
# Episode: 193, Time step: 50
# Episode: 193, Time step: 75
# Episode: 193, Time step: 100
# Episode: 193, Time step: 125
# Episode: 193, Time step: 150
# Episode: 193, Time step: 175
# Episode: 194, Time step: 0
# Episode: 194, Time step: 25
# Episode: 194, Time step: 50
# Episode: 194, Time step: 75
# Episode: 194, Time step: 100
# Episode: 194, Time step: 125
# Episode: 194, Time step: 150
# Episode: 194, Time step: 175
# Episode: 195, Time step: 0
# Episode: 195, Time step: 25
# Episode: 195, Time step: 50
# Episode: 195, Time step: 75
# Episode: 195, Time step: 100
# Episode: 195, Time step: 125
# Episode: 195, Time step: 150
# Episode: 195, Time step: 175
# Episode: 196, Time step: 0
# Episode: 196, Time step: 25
# Episode: 196, Time step: 50
# Episode: 196, Time step: 75
# Episode: 196, Time step: 100
# Episode: 196, Time step: 125
# Episode: 196, Time step: 150
# Episode: 196, Time step: 175
# Episode: 197, Time step: 0
# Episode: 197, Time step: 25
# Episode: 197, Time step: 50
# Episode: 197, Time step: 75
# Episode: 197, Time step: 100
# Episode: 197, Time step: 125
# Episode: 197, Time step: 150
# Episode: 197, Time step: 175
# Episode: 198, Time step: 0
# Episode: 198, Time step: 25
# Episode: 198, Time step: 50
# Episode: 198, Time step: 75
# Episode: 198, Time step: 100
# Episode: 198, Time step: 125
# Episode: 198, Time step: 150
# Episode: 198, Time step: 175
# Episode: 199, Time step: 0
# Episode: 199, Time step: 25
# Episode: 199, Time step: 50
# Episode: 199, Time step: 75
# Episode: 199, Time step: 100
# Episode: 199, Time step: 125
# Episode: 199, Time step: 150
# Episode: 199, Time step: 175
# Episode: 200, Time step: 0
# Episode: 200, Time step: 25
# Episode: 200, Time step: 50
# Episode: 200, Time step: 75
# Episode: 200, Time step: 100
# Episode: 200, Time step: 125
# Episode: 200, Time step: 150
# Episode: 200, Time step: 175
# Episode: 201, Time step: 0
# Episode: 201, Time step: 25
# Episode: 201, Time step: 50
# Episode: 201, Time step: 75
# Episode: 201, Time step: 100
# Episode: 201, Time step: 125
# Episode: 201, Time step: 150
# Episode: 201, Time step: 175
# Episode: 202, Time step: 0
# Episode: 202, Time step: 25
# Episode: 202, Time step: 50
# Episode: 202, Time step: 75
# Episode: 202, Time step: 100
# Episode: 202, Time step: 125
# Episode: 202, Time step: 150
# Episode: 202, Time step: 175
# Episode: 203, Time step: 0
# Episode: 203, Time step: 25
# Episode: 203, Time step: 50
# Episode: 203, Time step: 75
# Episode: 203, Time step: 100
# Episode: 203, Time step: 125
# Episode: 203, Time step: 150
# Episode: 203, Time step: 175
# Episode: 204, Time step: 0
# Episode: 204, Time step: 25
# Episode: 204, Time step: 50
# Episode: 204, Time step: 75
# Episode: 204, Time step: 100
# Episode: 204, Time step: 125
# Episode: 204, Time step: 150
# Episode: 204, Time step: 175
# Episode: 205, Time step: 0
# Episode: 205, Time step: 25
# Episode: 205, Time step: 50
# Episode: 205, Time step: 75
# Episode: 205, Time step: 100
# Episode: 205, Time step: 125
# Episode: 205, Time step: 150
# Episode: 205, Time step: 175
# Episode: 206, Time step: 0
# Episode: 206, Time step: 25
# Episode: 206, Time step: 50
# Episode: 206, Time step: 75
# Episode: 206, Time step: 100
# Episode: 206, Time step: 125
# Episode: 206, Time step: 150
# Episode: 206, Time step: 175
# Episode: 207, Time step: 0
# Episode: 207, Time step: 25
# Episode: 207, Time step: 50
# Episode: 207, Time step: 75
# Episode: 207, Time step: 100
# Episode: 207, Time step: 125
# Episode: 207, Time step: 150
# Episode: 207, Time step: 175
# Episode: 208, Time step: 0
# Episode: 208, Time step: 25
# Episode: 208, Time step: 50
# Episode: 208, Time step: 75
# Episode: 208, Time step: 100
# Episode: 208, Time step: 125
# Episode: 208, Time step: 150
# Episode: 208, Time step: 175
# Episode: 209, Time step: 0
# Episode: 209, Time step: 25
# Episode: 209, Time step: 50
# Episode: 209, Time step: 75
# Episode: 209, Time step: 100
# Episode: 209, Time step: 125
# Episode: 209, Time step: 150
# Episode: 209, Time step: 175
# Episode: 210, Time step: 0
# Episode: 210, Time step: 25
# Episode: 210, Time step: 50
# Episode: 210, Time step: 75
# Episode: 210, Time step: 100
# Episode: 210, Time step: 125
# Episode: 210, Time step: 150
# Episode: 210, Time step: 175
# Episode: 211, Time step: 0
# Episode: 211, Time step: 25
# Episode: 211, Time step: 50
# Episode: 211, Time step: 75
# Episode: 211, Time step: 100
# Episode: 211, Time step: 125
# Episode: 211, Time step: 150
# Episode: 211, Time step: 175
# Episode: 212, Time step: 0
# Episode: 212, Time step: 25
# Episode: 212, Time step: 50
# Episode: 212, Time step: 75
# Episode: 212, Time step: 100
# Episode: 212, Time step: 125
# Episode: 212, Time step: 150
# Episode: 212, Time step: 175
# Episode: 213, Time step: 0
# Episode: 213, Time step: 25
# Episode: 213, Time step: 50
# Episode: 213, Time step: 75
# Episode: 213, Time step: 100
# Episode: 213, Time step: 125
# Episode: 213, Time step: 150
# Episode: 213, Time step: 175
# Episode: 214, Time step: 0
# ...
# Episode: 529, Time step: 125
# Episode: 529, Time step: 150
# Episode: 529, Time step: 175
# Episode: 530, Time step: 0
# Episode: 530, Time step: 25
# Episode: 530, Time step: 50
# Episode: 530, Time step: 75
# Episode: 530, Time step: 100
# Episode: 530, Time step: 125
# Episode: 530, Time step: 150
# Episode: 530, Time step: 175
# Episode: 531, Time step: 0
# Episode: 531, Time step: 25
# Episode: 531, Time step: 50
# Episode: 531, Time step: 75
# Episode: 531, Time step: 100
# Episode: 531, Time step: 125
# Episode: 531, Time step: 150
# Episode: 531, Time step: 175
# Episode: 532, Time step: 0
# Episode: 532, Time step: 25
# Episode: 532, Time step: 50
# Episode: 532, Time step: 75
# Episode: 532, Time step: 100
# Episode: 532, Time step: 125
# Episode: 532, Time step: 150
# Episode: 532, Time step: 175
# Episode: 533, Time step: 0
# Episode: 533, Time step: 25
# Episode: 533, Time step: 50
# Episode: 533, Time step: 75
# Episode: 533, Time step: 100
# Episode: 533, Time step: 125
# Episode: 533, Time step: 150
# Episode: 533, Time step: 175
# Episode: 534, Time step: 0
# Episode: 534, Time step: 25
# Episode: 534, Time step: 50
# Episode: 534, Time step: 75
# Episode: 534, Time step: 100
# Episode: 534, Time step: 125
# Episode: 534, Time step: 150
# Episode: 534, Time step: 175
# Episode: 535, Time step: 0
# Episode: 535, Time step: 25
# Episode: 535, Time step: 50
# Episode: 535, Time step: 75
# Episode: 535, Time step: 100
# Episode: 535, Time step: 125
# Episode: 535, Time step: 150
# Episode: 535, Time step: 175
# Episode: 536, Time step: 0
# Episode: 536, Time step: 25
# Episode: 536, Time step: 50
# Episode: 536, Time step: 75
# Episode: 536, Time step: 100
# Episode: 536, Time step: 125
# Episode: 536, Time step: 150
# Episode: 536, Time step: 175
# Episode: 537, Time step: 0
# Episode: 537, Time step: 25
# Episode: 537, Time step: 50
# Episode: 537, Time step: 75
# Episode: 537, Time step: 100
# Episode: 537, Time step: 125
# Episode: 537, Time step: 150
# Episode: 537, Time step: 175
# Episode: 538, Time step: 0
# Episode: 538, Time step: 25
# Episode: 538, Time step: 50
# Episode: 538, Time step: 75
# Episode: 538, Time step: 100
# Episode: 538, Time step: 125
# Episode: 538, Time step: 150
# Episode: 538, Time step: 175
# Episode: 539, Time step: 0
# Episode: 539, Time step: 25
# Episode: 539, Time step: 50
# Episode: 539, Time step: 75
# Episode: 539, Time step: 100
# Episode: 539, Time step: 125
# Episode: 539, Time step: 150
# Episode: 539, Time step: 175
# Episode: 540, Time step: 0
# Episode: 540, Time step: 25
# Episode: 540, Time step: 50
# Episode: 540, Time step: 75
# Episode: 540, Time step: 100
# Episode: 540, Time step: 125
# Episode: 540, Time step: 150
# Episode: 540, Time step: 175
# Episode: 541, Time step: 0
# Episode: 541, Time step: 25
# Episode: 541, Time step: 50
# Episode: 541, Time step: 75
# Episode: 541, Time step: 100
# Episode: 541, Time step: 125
# Episode: 541, Time step: 150
# Episode: 541, Time step: 175
# Episode: 542, Time step: 0
# Episode: 542, Time step: 25
# Episode: 542, Time step: 50
# Episode: 542, Time step: 75
# Episode: 542, Time step: 100
# Episode: 542, Time step: 125
# Episode: 542, Time step: 150
# Episode: 542, Time step: 175
# Episode: 543, Time step: 0
# Episode: 543, Time step: 25
# Episode: 543, Time step: 50
# Episode: 543, Time step: 75
# Episode: 543, Time step: 100
# Episode: 543, Time step: 125
# Episode: 543, Time step: 150
# Episode: 543, Time step: 175
# Episode: 544, Time step: 0
# Episode: 544, Time step: 25
# Episode: 544, Time step: 50
# Episode: 544, Time step: 75
# Episode: 544, Time step: 100
# Episode: 544, Time step: 125
# Episode: 544, Time step: 150
# Episode: 544, Time step: 175
# Episode: 545, Time step: 0
# Episode: 545, Time step: 25
# Episode: 545, Time step: 50
# Episode: 545, Time step: 75
# Episode: 545, Time step: 100
# Episode: 545, Time step: 125
# Episode: 545, Time step: 150
# Episode: 545, Time step: 175
# Episode: 546, Time step: 0
# Episode: 546, Time step: 25
# Episode: 546, Time step: 50
# Episode: 546, Time step: 75
# Episode: 546, Time step: 100
# Episode: 546, Time step: 125
# Episode: 546, Time step: 150
# Episode: 546, Time step: 175
# Episode: 547, Time step: 0
# Episode: 547, Time step: 25
# Episode: 547, Time step: 50
# Episode: 547, Time step: 75
# Episode: 547, Time step: 100
# Episode: 547, Time step: 125
# Episode: 547, Time step: 150
# Episode: 547, Time step: 175
# Episode: 548, Time step: 0
# Episode: 548, Time step: 25
# Episode: 548, Time step: 50
# Episode: 548, Time step: 75
# Episode: 548, Time step: 100
# Episode: 548, Time step: 125
# Episode: 548, Time step: 150
# Episode: 548, Time step: 175
# Episode: 549, Time step: 0
# Episode: 549, Time step: 25
# Episode: 549, Time step: 50
# Episode: 549, Time step: 75
# Episode: 549, Time step: 100
# Episode: 549, Time step: 125
# Episode: 549, Time step: 150
# Episode: 549, Time step: 175
# Episode: 550, Time step: 0
# Episode: 550, Time step: 25
# Episode: 550, Time step: 50
# Episode: 550, Time step: 75
# Episode: 550, Time step: 100
# Episode: 550, Time step: 125
# Episode: 550, Time step: 150
# Episode: 550, Time step: 175
# Episode: 551, Time step: 0
# Episode: 551, Time step: 25
# Episode: 551, Time step: 50
# Episode: 551, Time step: 75
# Episode: 551, Time step: 100
# Episode: 551, Time step: 125
# Episode: 551, Time step: 150
# Episode: 551, Time step: 175
# Episode: 552, Time step: 0
# Episode: 552, Time step: 25
# Episode: 552, Time step: 50
# Episode: 552, Time step: 75
# Episode: 552, Time step: 100
# Episode: 552, Time step: 125
# Episode: 552, Time step: 150
# Episode: 552, Time step: 175
# Episode: 553, Time step: 0
# Episode: 553, Time step: 25
# Episode: 553, Time step: 50
# Episode: 553, Time step: 75
# Episode: 553, Time step: 100
# Episode: 553, Time step: 125
# Episode: 553, Time step: 150
# Episode: 553, Time step: 175
# Episode: 554, Time step: 0
# Episode: 554, Time step: 25
# Episode: 554, Time step: 50
# Episode: 554, Time step: 75
# Episode: 554, Time step: 100
# Episode: 554, Time step: 125
# Episode: 554, Time step: 150
# Episode: 554, Time step: 175
# Episode: 555, Time step: 0
# Episode: 555, Time step: 25
# Episode: 555, Time step: 50
# Episode: 555, Time step: 75
# Episode: 555, Time step: 100
# Episode: 555, Time step: 125
# Episode: 555, Time step: 150
# Episode: 555, Time step: 175
# Episode: 556, Time step: 0
# Episode: 556, Time step: 25
# Episode: 556, Time step: 50
# Episode: 556, Time step: 75
# Episode: 556, Time step: 100
# Episode: 556, Time step: 125
# Episode: 556, Time step: 150
# Episode: 556, Time step: 175
# Episode: 557, Time step: 0
# Episode: 557, Time step: 25
# Episode: 557, Time step: 50
# Episode: 557, Time step: 75
# Episode: 557, Time step: 100
# Episode: 557, Time step: 125
# Episode: 557, Time step: 150
# Episode: 557, Time step: 175
# Episode: 558, Time step: 0
# Episode: 558, Time step: 25
# Episode: 558, Time step: 50
# Episode: 558, Time step: 75
# Episode: 558, Time step: 100
# Episode: 558, Time step: 125
# Episode: 558, Time step: 150
# Episode: 558, Time step: 175
# Episode: 559, Time step: 0
# Episode: 559, Time step: 25
# Episode: 559, Time step: 50
# Episode: 559, Time step: 75
# Episode: 559, Time step: 100
# Episode: 559, Time step: 125
# Episode: 559, Time step: 150
# Episode: 559, Time step: 175
# Episode: 560, Time step: 0
# Episode: 560, Time step: 25
# Episode: 560, Time step: 50
# Episode: 560, Time step: 75
# Episode: 560, Time step: 100
# Episode: 560, Time step: 125
# Episode: 560, Time step: 150
# Episode: 560, Time step: 175
# Episode: 561, Time step: 0
# Episode: 561, Time step: 25
# Episode: 561, Time step: 50
# Episode: 561, Time step: 75
# Episode: 561, Time step: 100
# Episode: 561, Time step: 125
# Episode: 561, Time step: 150
# Episode: 561, Time step: 175
# Episode: 562, Time step: 0
# Episode: 562, Time step: 25
# Episode: 562, Time step: 50
# Episode: 562, Time step: 75
# Episode: 562, Time step: 100
# Episode: 562, Time step: 125
# Episode: 562, Time step: 150
# Episode: 562, Time step: 175
# Episode: 563, Time step: 0
# Episode: 563, Time step: 25
# Episode: 563, Time step: 50
# Episode: 563, Time step: 75
# Episode: 563, Time step: 100
# Episode: 563, Time step: 125
# Episode: 563, Time step: 150
# Episode: 563, Time step: 175
# Episode: 564, Time step: 0
# Episode: 564, Time step: 25
# Episode: 564, Time step: 50
# Episode: 564, Time step: 75
# Episode: 564, Time step: 100
# Episode: 564, Time step: 125
# Episode: 564, Time step: 150
# Episode: 564, Time step: 175
# Episode: 565, Time step: 0
# Episode: 565, Time step: 25
# Episode: 565, Time step: 50
# Episode: 565, Time step: 75
# Episode: 565, Time step: 100
# Episode: 565, Time step: 125
# Episode: 565, Time step: 150
# Episode: 565, Time step: 175
# Episode: 566, Time step: 0
# Episode: 566, Time step: 25
# Episode: 566, Time step: 50
# Episode: 566, Time step: 75
# Episode: 566, Time step: 100
# Episode: 566, Time step: 125
# Episode: 566, Time step: 150
# Episode: 566, Time step: 175
# Episode: 567, Time step: 0
# Episode: 567, Time step: 25
# Episode: 567, Time step: 50
# Episode: 567, Time step: 75
# Episode: 567, Time step: 100
# Episode: 567, Time step: 125
# Episode: 567, Time step: 150
# Episode: 567, Time step: 175
# Episode: 568, Time step: 0
# Episode: 568, Time step: 25
# Episode: 568, Time step: 50
# Episode: 568, Time step: 75
# Episode: 568, Time step: 100
# Episode: 568, Time step: 125
# Episode: 568, Time step: 150
# Episode: 568, Time step: 175
# Episode: 569, Time step: 0
# Episode: 569, Time step: 25
# Episode: 569, Time step: 50
# Episode: 569, Time step: 75
# Episode: 569, Time step: 100
# Episode: 569, Time step: 125
# Episode: 569, Time step: 150
# Episode: 569, Time step: 175
# Episode: 570, Time step: 0
# Episode: 570, Time step: 25
# Episode: 570, Time step: 50
# Episode: 570, Time step: 75
# Episode: 570, Time step: 100
# Episode: 570, Time step: 125
# Episode: 570, Time step: 150
# Episode: 570, Time step: 175
# Episode: 571, Time step: 0
# Episode: 571, Time step: 25
# Episode: 571, Time step: 50
# Episode: 571, Time step: 75
# Episode: 571, Time step: 100
# Episode: 571, Time step: 125
# Episode: 571, Time step: 150
# Episode: 571, Time step: 175
# Episode: 572, Time step: 0
# Episode: 572, Time step: 25
# Episode: 572, Time step: 50
# Episode: 572, Time step: 75
# Episode: 572, Time step: 100
# Episode: 572, Time step: 125
# Episode: 572, Time step: 150
# Episode: 572, Time step: 175
# Episode: 573, Time step: 0
# Episode: 573, Time step: 25
# Episode: 573, Time step: 50
# Episode: 573, Time step: 75
# Episode: 573, Time step: 100
# Episode: 573, Time step: 125
# Episode: 573, Time step: 150
# Episode: 573, Time step: 175
# Episode: 574, Time step: 0
# Episode: 574, Time step: 25
# Episode: 574, Time step: 50
# Episode: 574, Time step: 75
# Episode: 574, Time step: 100
# Episode: 574, Time step: 125
# Episode: 574, Time step: 150
# Episode: 574, Time step: 175
# Episode: 575, Time step: 0
# Episode: 575, Time step: 25
# Episode: 575, Time step: 50
# Episode: 575, Time step: 75
# Episode: 575, Time step: 100
# Episode: 575, Time step: 125
# Episode: 575, Time step: 150
# Episode: 575, Time step: 175
# Episode: 576, Time step: 0
# Episode: 576, Time step: 25
# Episode: 576, Time step: 50
# Episode: 576, Time step: 75
# Episode: 576, Time step: 100
# Episode: 576, Time step: 125
# Episode: 576, Time step: 150
# Episode: 576, Time step: 175
# Episode: 577, Time step: 0
# Episode: 577, Time step: 25
# Episode: 577, Time step: 50
# Episode: 577, Time step: 75
# Episode: 577, Time step: 100
# Episode: 577, Time step: 125
# Episode: 577, Time step: 150
# Episode: 577, Time step: 175
# Episode: 578, Time step: 0
# Episode: 578, Time step: 25
# Episode: 578, Time step: 50
# Episode: 578, Time step: 75
# Episode: 578, Time step: 100
# Episode: 578, Time step: 125
# Episode: 578, Time step: 150
# Episode: 578, Time step: 175
# Episode: 579, Time step: 0
# Episode: 579, Time step: 25
# Episode: 579, Time step: 50
# Episode: 579, Time step: 75
# Episode: 579, Time step: 100
# Episode: 579, Time step: 125
# Episode: 579, Time step: 150
# Episode: 579, Time step: 175
# Episode: 580, Time step: 0
# Episode: 580, Time step: 25
# Episode: 580, Time step: 50
# Episode: 580, Time step: 75
# Episode: 580, Time step: 100
# Episode: 580, Time step: 125
# Episode: 580, Time step: 150
# Episode: 580, Time step: 175
# Episode: 581, Time step: 0
# Episode: 581, Time step: 25
# Episode: 581, Time step: 50
# Episode: 581, Time step: 75
# Episode: 581, Time step: 100
# Episode: 581, Time step: 125
# Episode: 581, Time step: 150
# Episode: 581, Time step: 175
# Episode: 582, Time step: 0
# Episode: 582, Time step: 25
# Episode: 582, Time step: 50
# Episode: 582, Time step: 75
# Episode: 582, Time step: 100
# Episode: 582, Time step: 125
# Episode: 582, Time step: 150
# Episode: 582, Time step: 175
# Episode: 583, Time step: 0
# Episode: 583, Time step: 25
# Episode: 583, Time step: 50
# Episode: 583, Time step: 75
# Episode: 583, Time step: 100
# Episode: 583, Time step: 125
# Episode: 583, Time step: 150
# Episode: 583, Time step: 175
# Episode: 584, Time step: 0
# Episode: 584, Time step: 25
# Episode: 584, Time step: 50
# Episode: 584, Time step: 75
# Episode: 584, Time step: 100
# Episode: 584, Time step: 125
# Episode: 584, Time step: 150
# Episode: 584, Time step: 175
# Episode: 585, Time step: 0
# Episode: 585, Time step: 25
# Episode: 585, Time step: 50
# Episode: 585, Time step: 75
# Episode: 585, Time step: 100
# Episode: 585, Time step: 125
# Episode: 585, Time step: 150
# Episode: 585, Time step: 175
# Episode: 586, Time step: 0
# Episode: 586, Time step: 25
# Episode: 586, Time step: 50
# Episode: 586, Time step: 75
# Episode: 586, Time step: 100
# Episode: 586, Time step: 125
# Episode: 586, Time step: 150
# Episode: 586, Time step: 175
# Episode: 587, Time step: 0
# Episode: 587, Time step: 25
# Episode: 587, Time step: 50
# Episode: 587, Time step: 75
# Episode: 587, Time step: 100
# Episode: 587, Time step: 125
# Episode: 587, Time step: 150
# Episode: 587, Time step: 175
# Episode: 588, Time step: 0
# Episode: 588, Time step: 25
# Episode: 588, Time step: 50
# Episode: 588, Time step: 75
# Episode: 588, Time step: 100
# Episode: 588, Time step: 125
# Episode: 588, Time step: 150
# Episode: 588, Time step: 175
# Episode: 589, Time step: 0
# Episode: 589, Time step: 25
# Episode: 589, Time step: 50
# Episode: 589, Time step: 75
# Episode: 589, Time step: 100
# Episode: 589, Time step: 125
# Episode: 589, Time step: 150
# Episode: 589, Time step: 175
# Episode: 590, Time step: 0
# Episode: 590, Time step: 25
# Episode: 590, Time step: 50
# Episode: 590, Time step: 75
# Episode: 590, Time step: 100
# Episode: 590, Time step: 125
# Episode: 590, Time step: 150
# Episode: 590, Time step: 175
# Episode: 591, Time step: 0
# Episode: 591, Time step: 25
# Episode: 591, Time step: 50
# Episode: 591, Time step: 75
# Episode: 591, Time step: 100
# Episode: 591, Time step: 125
# Episode: 591, Time step: 150
# Episode: 591, Time step: 175
# Episode: 592, Time step: 0
# Episode: 592, Time step: 25
# Episode: 592, Time step: 50
# Episode: 592, Time step: 75
# Episode: 592, Time step: 100
# Episode: 592, Time step: 125
# Episode: 592, Time step: 150
# Episode: 592, Time step: 175
# Episode: 593, Time step: 0
# Episode: 593, Time step: 25
# Episode: 593, Time step: 50
# Episode: 593, Time step: 75
# Episode: 593, Time step: 100
# Episode: 593, Time step: 125
# Episode: 593, Time step: 150
# Episode: 593, Time step: 175
# Episode: 594, Time step: 0
# Episode: 594, Time step: 25
# Episode: 594, Time step: 50
# Episode: 594, Time step: 75
# Episode: 594, Time step: 100
# Episode: 594, Time step: 125
# Episode: 594, Time step: 150
# Episode: 594, Time step: 175
# Episode: 595, Time step: 0
# Episode: 595, Time step: 25
# Episode: 595, Time step: 50
# Episode: 595, Time step: 75
# Episode: 595, Time step: 100
# Episode: 595, Time step: 125
# Episode: 595, Time step: 150
# Episode: 595, Time step: 175
# Episode: 596, Time step: 0
# Episode: 596, Time step: 25
# Episode: 596, Time step: 50
# Episode: 596, Time step: 75
# Episode: 596, Time step: 100
# Episode: 596, Time step: 125
# Episode: 596, Time step: 150
# Episode: 596, Time step: 175
# Episode: 597, Time step: 0
# Episode: 597, Time step: 25
# Episode: 597, Time step: 50
# Episode: 597, Time step: 75
# Episode: 597, Time step: 100
# Episode: 597, Time step: 125
# Episode: 597, Time step: 150
# Episode: 597, Time step: 175
# Episode: 598, Time step: 0
# Episode: 598, Time step: 25
# Episode: 598, Time step: 50
# Episode: 598, Time step: 75
# Episode: 598, Time step: 100
# Episode: 598, Time step: 125
# Episode: 598, Time step: 150
# Episode: 598, Time step: 175
# Episode: 599, Time step: 0
# Episode: 599, Time step: 25
# Episode: 599, Time step: 50
# Episode: 599, Time step: 75
# Episode: 599, Time step: 100
# Episode: 599, Time step: 125
# Episode: 599, Time step: 150
# Episode: 599, Time step: 175

# %%
# Load the results 
reward_per_time_step = np.load('reward_per_time_step.npy')
average_reward_per_episode = np.load('average_reward_per_episode.npy')
x_coordinate_per_time_step = np.load('x_coordinate_per_time_step.npy')
y_coordinate_per_time_step = np.load('y_coordinate_per_time_step.npy')
angular_velocity_per_time_step = np.load('angular_velocity_per_time_step.npy')
action_per_time_step = np.load('action_per_time_step.npy')
num_time_steps = np.load('num_time_steps.npy')
num_episodes = np.load('num_episodes.npy')

# %%
t = np.argmax(average_reward_per_episode)

plt.figure(figsize=(15, 10))
plt.subplot(3,2,1)
plt.plot(np.arctan2(y_coordinate_per_time_step[t, :], x_coordinate_per_time_step[t, :]))
plt.xlabel('Time Step')
plt.ylabel('Theta (rad)')

plt.subplot(3,2,2)
plt.plot(angular_velocity_per_time_step[t, :])
plt.xlabel('Time Step')
plt.ylabel('Angular Velocity (rad/s)')

plt.subplot(3,2,3)
plt.plot(x_coordinate_per_time_step[t, :])
plt.xlabel('Time Step')
plt.ylabel('X-Coordinate (m)')

plt.subplot(3,2,4)
plt.plot(y_coordinate_per_time_step[t, :])
plt.xlabel('Time Step')
plt.ylabel('Y-Coordinate (m)')

plt.subplot(3,2,5)
plt.plot(action_per_time_step[t, :])
plt.xlabel('Time Step')
plt.ylabel('Torque (N.m)')

plt.subplot(3,2,6)
plt.plot([EPS_END + (EPS_START - EPS_END) * math.exp(-1. * s_d / EPS_DECAY) for s_d in range(num_time_steps)]);
plt.xlabel('Time Step')
plt.ylabel('Epsilon');

plt.tight_layout()

# %%
plt.plot(reward_per_time_step[t, :])
plt.xlabel('Time Step')
plt.ylabel('Reward');

# %%
plt.plot(average_reward_per_episode)
plt.xlabel('Episode')
plt.ylabel('Averaged Reward per Episode');
